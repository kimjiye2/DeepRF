# %%
def Bloch_simul_rot(x,y,z,T1,T2,RF,Gz,time_step,slice_thick,spatial_point,off_range, device):
    
    #     % units
    # % x, y, z : (spatial_point,1) for each
    # % T1, T2 : [msec]
    # % RF (2*N) : RF(1,:) is [Gauss], RF(2,:) row is angle [degree]
    # % Gz : [mT/m] (1 * N matrix) = [0.1 G/cm]
    # % time_step : pulse duration / sample points [msec]
    # % slice_thick : half of simulating thickness [m]
    # % spatial_point : number of points that are going to be simulated [#]
    # % 
    # % returns
    # % rot: (time series, 3, 3)

    T1 = T1 / 1000
    T2 = T2 / 1000

    length_RF = RF[0,:].shape[0]
    t_int = time_step * 1e-3

    # delta_omega = 2*pi*42.57747892*10^6 * (-1:2/(spatial_point-1):1).'*slice_thick*0.001*Gz;
    delta_omega = 2*np.pi*off_range.unsqueeze(1).repeat(1,256).to(device)
    RF_amp = (RF[0,:] * 2 * np.pi * 4257.747892).repeat(spatial_point, 1).to(device)
    RF_phase = ((RF[1,:]).repeat(spatial_point, 1)*np.pi/180).to(device)
    alpha = t_int * torch.sqrt(RF_amp ** 2 + delta_omega **2).to(device)
    
    zeta = torch.atan2(RF_amp, delta_omega)
    theta = RF_phase
    ca = torch.cos(alpha)
    sa = torch.sin(alpha)
    cz = torch.cos(zeta)
    sz = torch.sin(zeta)
    ct = torch.cos(theta)
    st = torch.sin(theta)
    E1 = np.exp(- t_int / T1)
    E2 = np.exp(- t_int / T2)
    Mx_x_part = ct*(E2*ct*(sz**2) + cz*(E2*sa*st + E2*ca*ct*cz)) + st*(E2*ca*st - E2*ct*cz*sa)
    Mx_y_part = st*(E2*ct*(sz**2) + cz*(E2*sa*st + E2*ca*ct*cz)) - ct*(E2*ca*st - E2*ct*cz*sa)
    Mx_z_part = E2*ct*cz*sz - sz*(E2*sa*st + E2*ca*ct*cz)
    My_x_part = - ct*(- E2*st*(sz**2) + cz*(E2*ct*sa - E2*ca*cz*st)) - st*(E2*ca*ct + E2*cz*sa*st)
    My_y_part = ct*(E2*ca*ct + E2*cz*sa*st) - st*(- E2*st*(sz**2) + cz*(E2*ct*sa - E2*ca*cz*st))
    My_z_part = sz*(E2*ct*sa - E2*ca*cz*st) + E2*cz*st*sz
    Mz_x_part = ct*(E1*cz*sz - E1*ca*cz*sz) + E1*sa*st*sz
    Mz_y_part = st*(E1*cz*sz - E1*ca*cz*sz) - E1*ct*sa*sz
    Mz_z_part = E1*(cz**2) + E1*ca*(sz**2);


    rot = torch.zeros((spatial_point,length_RF,3,3), device = device)
    rot[:,:,0,0] = Mx_x_part
    rot[:,:,0,1] = Mx_y_part
    rot[:,:,0,2] = Mx_z_part
    rot[:,:,1,0] = My_x_part
    rot[:,:,1,1] = My_y_part
    rot[:,:,1,2] = My_z_part
    rot[:,:,2,0] = Mz_x_part
    rot[:,:,2,1] = Mz_y_part
    rot[:,:,2,2] = Mz_z_part
    return rot

# %%
def RF_simul(RF_pulse, RF_img, off_range, time_step):
    size = RF_pulse.shape[0]
    RF_pulse_new = torch.zeros((size,2))
    RF_pulse_new[:,0] = torch.sqrt((RF_pulse**2+RF_img**2).squeeze())
    RF_pulse_new[:,1] = torch.angle(torch.complex(RF_pulse, RF_img).squeeze())

    max_rf_amp = torch.max(RF_pulse_new[:,0]) / (2*np.pi *42.577*1e+6*time_step*1e-4)
    rr = 42.577; # MHz/T
    Gz =  40; # mT/m (fixed)
    pos = torch.abs(off_range[0] / rr / Gz); # mm
    mag = (RF_pulse_new[:,0] / torch.max(RF_pulse_new[:,0]) )* max_rf_amp
    ph = (RF_pulse_new[:,1] / np.pi)*180

    pulse = torch.cat([mag.unsqueeze(1), ph.unsqueeze(1)], 1)
    pulse = torch.transpose(pulse, 0, 1)
    gg = torch.transpose(torch.ones((RF_pulse_new.shape[0],1)), 0, 1) * Gz

    freq_shape = off_range.shape[0]
    rot = Bloch_simul_rot(np.zeros([freq_shape,1]),np.zeros([freq_shape,1]),np.ones([freq_shape,1]),1e+10,1e+10,pulse,gg,time_step * 1e+3,pos * 0.001,freq_shape,off_range, device)

    return rot

# %%
from os import path
import sys

import os
import time
import argparse
import gym
import numpy as np
from scipy.io import loadmat
import torch
import torch.nn as nn
from torch.optim.lr_scheduler import ReduceLROnPlateau
import matplotlib.pyplot as plt
# Select GPU
os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"] = "7"

device = 'cuda' if torch.cuda.is_available() else 'cpu'

start_time = time.time()

# Hyperparameter setting
gamma = 2 * np.pi * 42.5775 * 1e+6
N_time_step = 256
max_RF_amp = 0.2 * 1e-4 #T
max_N_iter = 5000
mu = 0.0002  #learning rate
alpha = 0.05 # trade off between slice profile loss and sar
freq = torch.linspace(-8000, 8000, 2000) #Hz
T = 5.12*1e-3 #sec
k = freq.shape[0]
max_rad = max_RF_amp * gamma * T/N_time_step
time_step = T / N_time_step

# create B matrix
B1 = torch.zeros((3*k, 3*k), device = device)
B2 = torch.zeros((3*k, 3*k), device = device)

# create Projection matrix P
P = torch.zeros(3*k, 3*k, device = device)


for i in range(k) : 
    B1[i*3:(i+1)*3, i*3:(i+1)*3] = torch.from_numpy(np.array([[0,0,0], [0,0,1], [0,-1,0]]))
    B2[i*3:(i+1)*3, i*3:(i+1)*3] = torch.from_numpy(np.array([[0,0,-1], [0,0,0], [1,0,0]]))
    P[3*i+2, 3*i+2] = 1

# %%
from scipy.io import loadmat, savemat

a = loadmat('./SLR_inv_oc.mat')
slr = a['slr']
import torch
import numpy as np
rot = RF_simul(torch.from_numpy(slr), torch.zeros((256,1)).type(torch.DoubleTensor), torch.linspace(-8000,8000,2000), 5.12*1e-3/256)

# %%
Mt = torch.zeros([k, N_time_step+1, 3]).to(device)
Mt[:, 0, 2] = 1
torch.set_printoptions(threshold=5000)

for f in range(1, N_time_step+1):
    Mt[:, f, 0] = (Mt[:, f-1, 0] * rot[:, f-1, 0, 0]) +  (Mt[:, f-1, 1] * rot[:, f-1, 0, 1]) +  (Mt[:, f-1, 2] * rot[:, f-1, 0, 2] )
    Mt[:, f, 1] = (Mt[:, f-1, 0] * rot[:, f-1, 1, 0]) +  (Mt[:, f-1, 1] * rot[:, f-1, 1, 1]) +  (Mt[:, f-1, 2] * rot[:, f-1, 1, 2] )
    Mt[:, f, 2] = (Mt[:, f-1, 0] * rot[:, f-1, 2, 0]) +  (Mt[:, f-1, 1] * rot[:, f-1, 2, 1]) +  (Mt[:, f-1, 2] * rot[:, f-1, 2, 2])

D = Mt[:, -1, :].squeeze().reshape(-1, 1)
K = torch.mm(P, D);

# %%
# Create input vectors
preset = loadmat('./OC_input_inv_STA.mat')
w1 = np.array(preset['w1'], dtype=np.float32)
w2 = np.array(preset['w2'], dtype=np.float32)
w1 = torch.FloatTensor(w1)
w2 = torch.FloatTensor(w2)
w1 = w1.to(device)
w2 = w2.to(device)
# w1 = torch.from_numpy(slr).to(device)
# w1 = torch.transpose(w1,0,1)
# w2 = torch.zeros((256,1),device = device).type(torch.DoubleTensor)
# w2 = torch.transpose(w2,0,1).to(device)ㅋ

# %%
sar_loss = []
L2_loss  = []
total_loss = []
stop = 0 
#os.mkdir('./output/slr_oc')
preset = loadmat('./OC_input_inv_STA.mat')
w1 = np.array(preset['w1'], dtype=np.float32)
w2 = np.array(preset['w2'], dtype=np.float32)
w1 = torch.FloatTensor(w1)
w2 = torch.FloatTensor(w2)
w1 = w1.to(device)
w2 = w2.to(device)
import time
start_time = time.time()
for e in range(max_N_iter):
    Mt = torch.zeros([k, N_time_step+1, 3], device = device)
    Mt[:, 0, 2] = 1
    rot = (RF_simul(torch.transpose(w1,0,1).to(device), torch.transpose(w2,0,1).to(device), freq.to(device), T/N_time_step)).squeeze()

    for f in range(1 ,N_time_step+1):
        Mt[:, f, 0] = Mt[:, f-1, 0] * rot[:, f-1, 0, 0] +  Mt[:, f-1, 1] * rot[:, f-1, 0, 1] +  Mt[:, f-1, 2] * rot[:, f-1, 0, 2] 
        Mt[:, f, 1] = Mt[:, f-1, 0] * rot[:, f-1, 1, 0] +  Mt[:, f-1, 1] * rot[:, f-1, 1, 1] +  Mt[:, f-1, 2] * rot[:, f-1, 1, 2] 
        Mt[:, f, 2] = Mt[:, f-1, 0] * rot[:, f-1, 2, 0] +  Mt[:, f-1, 1] * rot[:, f-1, 2, 1] +  Mt[:, f-1, 2] * rot[:, f-1, 2, 2] 

    Mt = Mt[:, 1:, :]

    M_T = (Mt[:, -1, :]).squeeze().reshape(-1, 1)
    lambda_T = torch.transpose((torch.mm(torch.mm(torch.transpose(P, 0,1),P), M_T) - torch.mm(torch.transpose(P,0,1), K)),0,1)

    lambda_ = torch.zeros((k, N_time_step, 3), device = device)
    lambda_[:, -1, 0] = lambda_T[:, 0:3*k:3]
    lambda_[:, -1, 1] = lambda_T[:, 1:3*k:3]
    lambda_[:, -1, 2] = lambda_T[:, 2:3*k:3]

    for b in range(N_time_step-1, 0, -1):
        lambda_[:, b-1, 0] = lambda_[:, b, 0] * rot[:, b, 0, 0] + lambda_[:, b, 1] * rot[:, b, 1, 0] + lambda_[:, b, 2] * rot[:, b, 2, 0]
        lambda_[:, b-1, 1] = lambda_[:, b, 0] * rot[:, b, 0, 1] + lambda_[:, b, 1] * rot[:, b, 1, 1] + lambda_[:, b, 2] * rot[:, b, 2, 1]
        lambda_[:, b-1, 2] = lambda_[:, b, 0] * rot[:, b, 0, 2] + lambda_[:, b, 1] * rot[:, b, 1, 2] + lambda_[:, b, 2] * rot[:, b, 2, 2]

    # Update rf pulse
    for u in range(N_time_step):
        M = Mt[:, u, :].squeeze().reshape(-1,1).to(device)
        lamb = lambda_[:, u, :].squeeze().reshape(-1, 1).to(device)
        w1[:, u] = w1[:, u] - mu * (torch.mm(torch.mm(torch.transpose(lamb, 0, 1), B1), M) + alpha * w1[:, u])
        w2[:, u] = w2[:, u] - mu * (torch.mm(torch.mm(torch.transpose(lamb, 0, 1), B2), M) + alpha * w2[:, u])


    M_ = (Mt[:, -1, :]).squeeze().reshape(-1, 1)
    dist = torch.mm(P, M_) - K
    phi_d = (1/2 * (torch.mm(torch.transpose(dist, 0, 1), dist))).item()
    energy = torch.sum(w1**2 + w2**2)
    sar_loss.append(energy.detach().cpu().numpy())
    L2_loss.append(phi_d)
    loss = phi_d + alpha * energy 
    if e == 0 or (e +1) % 50 == 0:
        time_step = 5.12 * 1e-3 / 256 
        to_gauss = 2 * np.pi * 42.5775 * 1e+6 * time_step * 1e-4
        sar_slr = np.sum((slr/to_gauss)**2) * time_step * 1e+6

        sar_rf = torch.sum((w1**2 + w2 **2)) / (to_gauss**2) * time_step * 1e+6
        print("♨♨♨♨♨♨♨♨♨♨♨♨♨♨♨♨♨♨♨♨♨♨")
        print(f"Iteration : {e}")
        print(f"SAR of SLR : {sar_slr:.5f}")
        print(f"SAR of RF : {sar_rf:.5f}")
        print(f"SAR reduction : {(sar_slr - sar_rf)/sar_slr *100:.4f} %")
        energy = torch.sum(w1**2 + w2**2)
        M_ = (Mt[:, -1, :]).squeeze().reshape(-1, 1)
        dist = torch.matmul(P, M_) - K
        phi_d = (1/2 * (torch.mm(torch.transpose(dist, 0, 1), dist))).item()
        #savemat(f"./output/OC_result_inv8_STA_{e}_alpha{alpha}.mat", {"L2loss": L2_loss, "sar_loss" : sar_loss, "w1" : w1.detach().cpu().numpy(), "w2" : w2.detach().cpu().numpy(), "total_loss" : total_loss, "iteration" : e, "mu" : mu})
        print(f"iteration = {e}, phi_d = {phi_d:.5f}, energy = {energy.item():.5f}")

    if (e > 500) :
        if (loss.detach().cpu().numpy() > total_loss[-1]) :
            stop = stop + 1
        else :
            stop = 0 

        if(stop>5):
            break

    total_loss.append(loss.detach().cpu().numpy())

savemat(f"./output/sta/OC_result_inv8_STA_{e}_alpha{alpha}.mat", {"L2loss": L2_loss, "sar_loss" : sar_loss, "w1" : w1.detach().cpu().numpy(), "w2" : w2.detach().cpu().numpy(), "total loss" : total_loss, "iteration" : e, "mu" : mu})
print(f"Total time: {time.time() - start_time:.1f}")
# Out:
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 0
# SAR of SLR : 19.59590
# SAR of RF : 21.60244
# SAR reduction : -10.2396 %
# iteration = 0, phi_d = 18.92312, energy = 0.30921
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 49
# SAR of SLR : 19.59590
# SAR of RF : 20.60616
# SAR reduction : -5.1555 %
# iteration = 49, phi_d = 0.00602, energy = 0.29495
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 99
# SAR of SLR : 19.59590
# SAR of RF : 20.53591
# SAR reduction : -4.7970 %
# iteration = 99, phi_d = 0.00373, energy = 0.29394
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 149
# SAR of SLR : 19.59590
# SAR of RF : 20.46962
# SAR reduction : -4.4587 %
# iteration = 149, phi_d = 0.00288, energy = 0.29299
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 199
# SAR of SLR : 19.59590
# SAR of RF : 20.38912
# SAR reduction : -4.0479 %
# iteration = 199, phi_d = 0.00199, energy = 0.29184
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 249
# SAR of SLR : 19.59590
# SAR of RF : 20.30150
# SAR reduction : -3.6008 %
# iteration = 249, phi_d = 0.00092, energy = 0.29059
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 299
# SAR of SLR : 19.59590
# SAR of RF : 20.24220
# SAR reduction : -3.2982 %
# iteration = 299, phi_d = 0.00033, energy = 0.28974
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 349
# SAR of SLR : 19.59590
# SAR of RF : 20.21675
# SAR reduction : -3.1683 %
# iteration = 349, phi_d = 0.00019, energy = 0.28938
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 399
# SAR of SLR : 19.59590
# SAR of RF : 20.20350
# SAR reduction : -3.1006 %
# iteration = 399, phi_d = 0.00014, energy = 0.28919
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 449
# SAR of SLR : 19.59590
# SAR of RF : 20.19228
# SAR reduction : -3.0434 %
# iteration = 449, phi_d = 0.00012, energy = 0.28903
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 499
# SAR of SLR : 19.59590
# SAR of RF : 20.18098
# SAR reduction : -2.9857 %
# iteration = 499, phi_d = 0.00011, energy = 0.28886
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 549
# SAR of SLR : 19.59590
# SAR of RF : 20.16941
# SAR reduction : -2.9267 %
# iteration = 549, phi_d = 0.00010, energy = 0.28870
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 599
# SAR of SLR : 19.59590
# SAR of RF : 20.15769
# SAR reduction : -2.8669 %
# iteration = 599, phi_d = 0.00009, energy = 0.28853
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 649
# SAR of SLR : 19.59590
# SAR of RF : 20.14591
# SAR reduction : -2.8068 %
# iteration = 649, phi_d = 0.00008, energy = 0.28836
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 699
# SAR of SLR : 19.59590
# SAR of RF : 20.13413
# SAR reduction : -2.7467 %
# iteration = 699, phi_d = 0.00007, energy = 0.28819
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 749
# SAR of SLR : 19.59590
# SAR of RF : 20.12237
# SAR reduction : -2.6866 %
# iteration = 749, phi_d = 0.00007, energy = 0.28802
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 799
# SAR of SLR : 19.59590
# SAR of RF : 20.11065
# SAR reduction : -2.6268 %
# iteration = 799, phi_d = 0.00006, energy = 0.28786
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 849
# SAR of SLR : 19.59590
# SAR of RF : 20.09896
# SAR reduction : -2.5672 %
# iteration = 849, phi_d = 0.00006, energy = 0.28769
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 899
# SAR of SLR : 19.59590
# SAR of RF : 20.08732
# SAR reduction : -2.5078 %
# iteration = 899, phi_d = 0.00005, energy = 0.28752
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 949
# SAR of SLR : 19.59590
# SAR of RF : 20.07573
# SAR reduction : -2.4486 %
# iteration = 949, phi_d = 0.00005, energy = 0.28736
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 999
# SAR of SLR : 19.59590
# SAR of RF : 20.06417
# SAR reduction : -2.3896 %
# iteration = 999, phi_d = 0.00005, energy = 0.28719
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 1049
# SAR of SLR : 19.59590
# SAR of RF : 20.05264
# SAR reduction : -2.3308 %
# iteration = 1049, phi_d = 0.00004, energy = 0.28703
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 1099
# SAR of SLR : 19.59590
# SAR of RF : 20.04115
# SAR reduction : -2.2722 %
# iteration = 1099, phi_d = 0.00004, energy = 0.28686
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 1149
# SAR of SLR : 19.59590
# SAR of RF : 20.02969
# SAR reduction : -2.2137 %
# iteration = 1149, phi_d = 0.00004, energy = 0.28670
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 1199
# SAR of SLR : 19.59590
# SAR of RF : 20.01826
# SAR reduction : -2.1554 %
# iteration = 1199, phi_d = 0.00003, energy = 0.28653
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 1249
# SAR of SLR : 19.59590
# SAR of RF : 20.00686
# SAR reduction : -2.0972 %
# iteration = 1249, phi_d = 0.00003, energy = 0.28637
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 1299
# SAR of SLR : 19.59590
# SAR of RF : 19.99549
# SAR reduction : -2.0391 %
# iteration = 1299, phi_d = 0.00003, energy = 0.28621
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 1349
# SAR of SLR : 19.59590
# SAR of RF : 19.98414
# SAR reduction : -1.9813 %
# iteration = 1349, phi_d = 0.00003, energy = 0.28605
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 1399
# SAR of SLR : 19.59590
# SAR of RF : 19.97283
# SAR reduction : -1.9235 %
# iteration = 1399, phi_d = 0.00002, energy = 0.28588
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 1449
# SAR of SLR : 19.59590
# SAR of RF : 19.96154
# SAR reduction : -1.8659 %
# iteration = 1449, phi_d = 0.00002, energy = 0.28572
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 1499
# SAR of SLR : 19.59590
# SAR of RF : 19.95028
# SAR reduction : -1.8085 %
# iteration = 1499, phi_d = 0.00002, energy = 0.28556
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 1549
# SAR of SLR : 19.59590
# SAR of RF : 19.93905
# SAR reduction : -1.7512 %
# iteration = 1549, phi_d = 0.00002, energy = 0.28540
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 1599
# SAR of SLR : 19.59590
# SAR of RF : 19.92785
# SAR reduction : -1.6940 %
# iteration = 1599, phi_d = 0.00002, energy = 0.28524
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 1649
# SAR of SLR : 19.59590
# SAR of RF : 19.91668
# SAR reduction : -1.6370 %
# iteration = 1649, phi_d = 0.00002, energy = 0.28508
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 1699
# SAR of SLR : 19.59590
# SAR of RF : 19.90554
# SAR reduction : -1.5801 %
# iteration = 1699, phi_d = 0.00002, energy = 0.28492
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 1749
# SAR of SLR : 19.59590
# SAR of RF : 19.89442
# SAR reduction : -1.5234 %
# iteration = 1749, phi_d = 0.00001, energy = 0.28476
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 1799
# SAR of SLR : 19.59590
# SAR of RF : 19.88334
# SAR reduction : -1.4669 %
# iteration = 1799, phi_d = 0.00001, energy = 0.28460
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 1849
# SAR of SLR : 19.59590
# SAR of RF : 19.87228
# SAR reduction : -1.4104 %
# iteration = 1849, phi_d = 0.00001, energy = 0.28444
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 1899
# SAR of SLR : 19.59590
# SAR of RF : 19.86126
# SAR reduction : -1.3542 %
# iteration = 1899, phi_d = 0.00001, energy = 0.28429
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 1949
# SAR of SLR : 19.59590
# SAR of RF : 19.85026
# SAR reduction : -1.2980 %
# iteration = 1949, phi_d = 0.00001, energy = 0.28413
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 1999
# SAR of SLR : 19.59590
# SAR of RF : 19.83929
# SAR reduction : -1.2421 %
# iteration = 1999, phi_d = 0.00001, energy = 0.28397
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 2049
# SAR of SLR : 19.59590
# SAR of RF : 19.82835
# SAR reduction : -1.1862 %
# iteration = 2049, phi_d = 0.00001, energy = 0.28382
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 2099
# SAR of SLR : 19.59590
# SAR of RF : 19.81743
# SAR reduction : -1.1305 %
# iteration = 2099, phi_d = 0.00001, energy = 0.28366
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 2149
# SAR of SLR : 19.59590
# SAR of RF : 19.80654
# SAR reduction : -1.0749 %
# iteration = 2149, phi_d = 0.00001, energy = 0.28350
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 2199
# SAR of SLR : 19.59590
# SAR of RF : 19.79567
# SAR reduction : -1.0195 %
# iteration = 2199, phi_d = 0.00001, energy = 0.28335
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 2249
# SAR of SLR : 19.59590
# SAR of RF : 19.78484
# SAR reduction : -0.9642 %
# iteration = 2249, phi_d = 0.00001, energy = 0.28319
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 2299
# SAR of SLR : 19.59590
# SAR of RF : 19.77402
# SAR reduction : -0.9090 %
# iteration = 2299, phi_d = 0.00001, energy = 0.28304
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 2349
# SAR of SLR : 19.59590
# SAR of RF : 19.76323
# SAR reduction : -0.8539 %
# iteration = 2349, phi_d = 0.00001, energy = 0.28288
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 2399
# SAR of SLR : 19.59590
# SAR of RF : 19.75245
# SAR reduction : -0.7989 %
# iteration = 2399, phi_d = 0.00001, energy = 0.28273
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 2449
# SAR of SLR : 19.59590
# SAR of RF : 19.74170
# SAR reduction : -0.7441 %
# iteration = 2449, phi_d = 0.00001, energy = 0.28258
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 2499
# SAR of SLR : 19.59590
# SAR of RF : 19.73097
# SAR reduction : -0.6893 %
# iteration = 2499, phi_d = 0.00001, energy = 0.28242
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 2549
# SAR of SLR : 19.59590
# SAR of RF : 19.72025
# SAR reduction : -0.6346 %
# iteration = 2549, phi_d = 0.00001, energy = 0.28227
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 2599
# SAR of SLR : 19.59590
# SAR of RF : 19.70955
# SAR reduction : -0.5800 %
# iteration = 2599, phi_d = 0.00001, energy = 0.28212
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 2649
# SAR of SLR : 19.59590
# SAR of RF : 19.69887
# SAR reduction : -0.5255 %
# iteration = 2649, phi_d = 0.00001, energy = 0.28196
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 2699
# SAR of SLR : 19.59590
# SAR of RF : 19.68821
# SAR reduction : -0.4711 %
# iteration = 2699, phi_d = 0.00001, energy = 0.28181
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 2749
# SAR of SLR : 19.59590
# SAR of RF : 19.67756
# SAR reduction : -0.4167 %
# iteration = 2749, phi_d = 0.00001, energy = 0.28166
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 2799
# SAR of SLR : 19.59590
# SAR of RF : 19.66691
# SAR reduction : -0.3624 %
# iteration = 2799, phi_d = 0.00001, energy = 0.28151
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 2849
# SAR of SLR : 19.59590
# SAR of RF : 19.65629
# SAR reduction : -0.3082 %
# iteration = 2849, phi_d = 0.00001, energy = 0.28135
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 2899
# SAR of SLR : 19.59590
# SAR of RF : 19.64567
# SAR reduction : -0.2540 %
# iteration = 2899, phi_d = 0.00001, energy = 0.28120
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 2949
# SAR of SLR : 19.59590
# SAR of RF : 19.63506
# SAR reduction : -0.1999 %
# iteration = 2949, phi_d = 0.00001, energy = 0.28105
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 2999
# SAR of SLR : 19.59590
# SAR of RF : 19.62447
# SAR reduction : -0.1458 %
# iteration = 2999, phi_d = 0.00001, energy = 0.28090
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 3049
# SAR of SLR : 19.59590
# SAR of RF : 19.61388
# SAR reduction : -0.0918 %
# iteration = 3049, phi_d = 0.00001, energy = 0.28075
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 3099
# SAR of SLR : 19.59590
# SAR of RF : 19.60330
# SAR reduction : -0.0378 %
# iteration = 3099, phi_d = 0.00001, energy = 0.28059
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 3149
# SAR of SLR : 19.59590
# SAR of RF : 19.59273
# SAR reduction : 0.0162 %
# iteration = 3149, phi_d = 0.00001, energy = 0.28044
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 3199
# SAR of SLR : 19.59590
# SAR of RF : 19.58217
# SAR reduction : 0.0701 %
# iteration = 3199, phi_d = 0.00001, energy = 0.28029
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 3249
# SAR of SLR : 19.59590
# SAR of RF : 19.57161
# SAR reduction : 0.1239 %
# iteration = 3249, phi_d = 0.00001, energy = 0.28014
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 3299
# SAR of SLR : 19.59590
# SAR of RF : 19.56106
# SAR reduction : 0.1778 %
# iteration = 3299, phi_d = 0.00001, energy = 0.27999
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 3349
# SAR of SLR : 19.59590
# SAR of RF : 19.55052
# SAR reduction : 0.2316 %
# iteration = 3349, phi_d = 0.00001, energy = 0.27984
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 3399
# SAR of SLR : 19.59590
# SAR of RF : 19.53998
# SAR reduction : 0.2853 %
# iteration = 3399, phi_d = 0.00000, energy = 0.27969
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 3449
# SAR of SLR : 19.59590
# SAR of RF : 19.52945
# SAR reduction : 0.3391 %
# iteration = 3449, phi_d = 0.00000, energy = 0.27954
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 3499
# SAR of SLR : 19.59590
# SAR of RF : 19.51892
# SAR reduction : 0.3928 %
# iteration = 3499, phi_d = 0.00000, energy = 0.27939
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 3549
# SAR of SLR : 19.59590
# SAR of RF : 19.50841
# SAR reduction : 0.4465 %
# iteration = 3549, phi_d = 0.00000, energy = 0.27924
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 3599
# SAR of SLR : 19.59590
# SAR of RF : 19.49790
# SAR reduction : 0.5001 %
# iteration = 3599, phi_d = 0.00000, energy = 0.27909
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 3649
# SAR of SLR : 19.59590
# SAR of RF : 19.48740
# SAR reduction : 0.5537 %
# iteration = 3649, phi_d = 0.00000, energy = 0.27894
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 3699
# SAR of SLR : 19.59590
# SAR of RF : 19.47690
# SAR reduction : 0.6072 %
# iteration = 3699, phi_d = 0.00000, energy = 0.27879
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 3749
# SAR of SLR : 19.59590
# SAR of RF : 19.46641
# SAR reduction : 0.6608 %
# iteration = 3749, phi_d = 0.00000, energy = 0.27864
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 3799
# SAR of SLR : 19.59590
# SAR of RF : 19.45592
# SAR reduction : 0.7143 %
# iteration = 3799, phi_d = 0.00000, energy = 0.27849
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 3849
# SAR of SLR : 19.59590
# SAR of RF : 19.44544
# SAR reduction : 0.7678 %
# iteration = 3849, phi_d = 0.00000, energy = 0.27833
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 3899
# SAR of SLR : 19.59590
# SAR of RF : 19.43497
# SAR reduction : 0.8212 %
# iteration = 3899, phi_d = 0.00000, energy = 0.27819
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 3949
# SAR of SLR : 19.59590
# SAR of RF : 19.42450
# SAR reduction : 0.8747 %
# iteration = 3949, phi_d = 0.00000, energy = 0.27804
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 3999
# SAR of SLR : 19.59590
# SAR of RF : 19.41404
# SAR reduction : 0.9281 %
# iteration = 3999, phi_d = 0.00000, energy = 0.27789
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 4049
# SAR of SLR : 19.59590
# SAR of RF : 19.40358
# SAR reduction : 0.9814 %
# iteration = 4049, phi_d = 0.00000, energy = 0.27774
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 4099
# SAR of SLR : 19.59590
# SAR of RF : 19.39314
# SAR reduction : 1.0347 %
# iteration = 4099, phi_d = 0.00000, energy = 0.27759
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 4149
# SAR of SLR : 19.59590
# SAR of RF : 19.38270
# SAR reduction : 1.0880 %
# iteration = 4149, phi_d = 0.00000, energy = 0.27744
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 4199
# SAR of SLR : 19.59590
# SAR of RF : 19.37227
# SAR reduction : 1.1412 %
# iteration = 4199, phi_d = 0.00000, energy = 0.27729
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 4249
# SAR of SLR : 19.59590
# SAR of RF : 19.36185
# SAR reduction : 1.1944 %
# iteration = 4249, phi_d = 0.00000, energy = 0.27714
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 4299
# SAR of SLR : 19.59590
# SAR of RF : 19.35143
# SAR reduction : 1.2475 %
# iteration = 4299, phi_d = 0.00000, energy = 0.27699
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 4349
# SAR of SLR : 19.59590
# SAR of RF : 19.34103
# SAR reduction : 1.3006 %
# iteration = 4349, phi_d = 0.00000, energy = 0.27684
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 4399
# SAR of SLR : 19.59590
# SAR of RF : 19.33064
# SAR reduction : 1.3536 %
# iteration = 4399, phi_d = 0.00000, energy = 0.27669
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 4449
# SAR of SLR : 19.59590
# SAR of RF : 19.32026
# SAR reduction : 1.4066 %
# iteration = 4449, phi_d = 0.00000, energy = 0.27654
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 4499
# SAR of SLR : 19.59590
# SAR of RF : 19.30989
# SAR reduction : 1.4595 %
# iteration = 4499, phi_d = 0.00000, energy = 0.27639
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 4549
# SAR of SLR : 19.59590
# SAR of RF : 19.29953
# SAR reduction : 1.5124 %
# iteration = 4549, phi_d = 0.00000, energy = 0.27625
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 4599
# SAR of SLR : 19.59590
# SAR of RF : 19.28919
# SAR reduction : 1.5652 %
# iteration = 4599, phi_d = 0.00000, energy = 0.27610
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 4649
# SAR of SLR : 19.59590
# SAR of RF : 19.27886
# SAR reduction : 1.6179 %
# iteration = 4649, phi_d = 0.00000, energy = 0.27595
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 4699
# SAR of SLR : 19.59590
# SAR of RF : 19.26855
# SAR reduction : 1.6705 %
# iteration = 4699, phi_d = 0.00000, energy = 0.27580
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 4749
# SAR of SLR : 19.59590
# SAR of RF : 19.25825
# SAR reduction : 1.7230 %
# iteration = 4749, phi_d = 0.00000, energy = 0.27566
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 4799
# SAR of SLR : 19.59590
# SAR of RF : 19.24797
# SAR reduction : 1.7755 %
# iteration = 4799, phi_d = 0.00000, energy = 0.27551
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 4849
# SAR of SLR : 19.59590
# SAR of RF : 19.23771
# SAR reduction : 1.8279 %
# iteration = 4849, phi_d = 0.00000, energy = 0.27536
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 4899
# SAR of SLR : 19.59590
# SAR of RF : 19.22746
# SAR reduction : 1.8802 %
# iteration = 4899, phi_d = 0.00000, energy = 0.27521
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 4949
# SAR of SLR : 19.59590
# SAR of RF : 19.21722
# SAR reduction : 1.9324 %
# iteration = 4949, phi_d = 0.00000, energy = 0.27507
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 4999
# SAR of SLR : 19.59590
# SAR of RF : 19.20701
# SAR reduction : 1.9845 %
# iteration = 4999, phi_d = 0.00000, energy = 0.27492
# Total time: 1684.5

# %%
savemat(f"./output/sta/OC_result_inv8_STA_{e}_alpha{alpha}.mat", {"L2loss": L2_loss, "sar_loss" : sar_loss, "w1" : w1.detach().cpu().numpy(), "w2" : w2.detach().cpu().numpy(), "total loss" : total_loss, "iteration" : e, "mu" : mu})
