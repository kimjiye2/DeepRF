# %%
def Bloch_simul_rot(x,y,z,T1,T2,RF,Gz,time_step,slice_thick,spatial_point,off_range):
    
    #     % units
    # % x, y, z : (spatial_point,1) for each
    # % T1, T2 : [msec]
    # % RF (2*N) : RF(1,:) is [Gauss], RF(2,:) row is angle [degree]
    # % Gz : [mT/m] (1 * N matrix) = [0.1 G/cm]
    # % time_step : pulse duration / sample points [msec]
    # % slice_thick : half of simulating thickness [m]
    # % spatial_point : number of points that are going to be simulated [#]
    # % 
    # % returns
    # % rot: (time series, 3, 3)

    T1 = T1 / 1000
    T2 = T2 / 1000

    length_RF = RF[0,:].shape[0]
    t_int = time_step * 1e-3

    # delta_omega = 2*pi*42.57747892*10^6 * (-1:2/(spatial_point-1):1).'*slice_thick*0.001*Gz;
    delta_omega = 2*np.pi*off_range.unsqueeze(1).repeat(1,256)
    RF_amp = (RF[0,:] * 2 * np.pi * 4257.747892).repeat(spatial_point, 1)
    RF_phase = (RF[1,:]).repeat(spatial_point, 1)*np.pi/180;
    alpha = t_int * torch.sqrt(RF_amp ** 2 + delta_omega **2)
    
    zeta = torch.atan2(RF_amp, delta_omega)
    theta = RF_phase
    ca = torch.cos(alpha)
    sa = torch.sin(alpha)
    cz = torch.cos(zeta)
    sz = torch.sin(zeta)
    ct = torch.cos(theta)
    st = torch.sin(theta)
    E1 = np.exp(- t_int / T1)
    E2 = np.exp(- t_int / T2)
    Mx_x_part = ct*(E2*ct*(sz**2) + cz*(E2*sa*st + E2*ca*ct*cz)) + st*(E2*ca*st - E2*ct*cz*sa)
    Mx_y_part = st*(E2*ct*(sz**2) + cz*(E2*sa*st + E2*ca*ct*cz)) - ct*(E2*ca*st - E2*ct*cz*sa)
    Mx_z_part = E2*ct*cz*sz - sz*(E2*sa*st + E2*ca*ct*cz)
    My_x_part = - ct*(- E2*st*(sz**2) + cz*(E2*ct*sa - E2*ca*cz*st)) - st*(E2*ca*ct + E2*cz*sa*st)
    My_y_part = ct*(E2*ca*ct + E2*cz*sa*st) - st*(- E2*st*(sz**2) + cz*(E2*ct*sa - E2*ca*cz*st))
    My_z_part = sz*(E2*ct*sa - E2*ca*cz*st) + E2*cz*st*sz
    Mz_x_part = ct*(E1*cz*sz - E1*ca*cz*sz) + E1*sa*st*sz
    Mz_y_part = st*(E1*cz*sz - E1*ca*cz*sz) - E1*ct*sa*sz
    Mz_z_part = E1*(cz**2) + E1*ca*(sz**2);


    rot = torch.zeros((spatial_point,length_RF,3,3))
    rot[:,:,0,0] = Mx_x_part
    rot[:,:,0,1] = Mx_y_part
    rot[:,:,0,2] = Mx_z_part
    rot[:,:,1,0] = My_x_part
    rot[:,:,1,1] = My_y_part
    rot[:,:,1,2] = My_z_part
    rot[:,:,2,0] = Mz_x_part
    rot[:,:,2,1] = Mz_y_part
    rot[:,:,2,2] = Mz_z_part
    return rot

# %%
def RF_simul(RF_pulse, RF_img, off_range, time_step):
    size = RF_pulse.shape[0]
    RF_pulse_new = torch.zeros((size,2))
    RF_pulse_new[:,0] = torch.sqrt((RF_pulse**2+RF_img**2).squeeze())
    RF_pulse_new[:,1] = torch.angle(torch.complex(RF_pulse, RF_img).squeeze())

    max_rf_amp = torch.max(RF_pulse_new[:,0]) / (2*np.pi *42.577*1e+6*time_step*1e-4)
    rr = 42.577; # MHz/T
    Gz =  40; # mT/m (fixed)
    pos = torch.abs(off_range[0] / rr / Gz); # mm
    mag = (RF_pulse_new[:,0] / torch.max(RF_pulse_new[:,0]) )* max_rf_amp
    ph = (RF_pulse_new[:,1] / np.pi)*180

    pulse = torch.cat([mag.unsqueeze(1), ph.unsqueeze(1)], 1)
    pulse = torch.transpose(pulse, 0, 1)
    gg = torch.transpose(torch.ones((RF_pulse_new.shape[0],1)), 0, 1) * Gz

    freq_shape = off_range.shape[0]
    rot = Bloch_simul_rot(np.zeros([freq_shape,1]),np.zeros([freq_shape,1]),np.ones([freq_shape,1]),1e+10,1e+10,pulse,gg,time_step * 1e+3,pos * 0.001,freq_shape,off_range).to(device)

    return rot

# %%
from os import path
import sys

import os
import time
import argparse
import gym
import numpy as np
from scipy.io import loadmat
import torch
import torch.nn as nn
from torch.optim.lr_scheduler import ReduceLROnPlateau
import matplotlib.pyplot as plt
# Select GPU
os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"] = "2"

device = 'cuda' if torch.cuda.is_available() else 'cpu'

start_time = time.time()

# Hyperparameter setting
gamma = 2 * np.pi * 42.5775 * 1e+6
N_time_step = 256
max_RF_amp = 0.2 * 1e-4 #T
max_N_iter = 10000
mu = 0.0002  #learning rate
alpha = 0.2795 # trade off between slice profile loss and sar
freq = torch.linspace(-8000, 8000, 2000) #Hz
T = 5.12*1e-3 #sec
k = freq.shape[0]
max_rad = max_RF_amp * gamma * T/N_time_step
time_step = T / N_time_step

# create B matrix
B1 = torch.zeros((3*k, 3*k)).to(device)
B2 = torch.zeros((3*k, 3*k)).to(device)

# create Projection matrix P
P = torch.zeros(3*k, 3*k).to(device)


for i in range(k) : 
    B1[i*3:(i+1)*3, i*3:(i+1)*3] = torch.from_numpy(np.array([[0,0,0], [0,0,1], [0,-1,0]]))
    B2[i*3:(i+1)*3, i*3:(i+1)*3] = torch.from_numpy(np.array([[0,0,-1], [0,0,0], [1,0,0]]))
    P[3*i+2, 3*i+2] = 1

# %%
from scipy.io import loadmat, savemat

a = loadmat('./SLR_inv_oc.mat')
slr = a['slr']
import torch
import numpy as np
rot = RF_simul(torch.from_numpy(slr), torch.zeros((256,1)).type(torch.DoubleTensor), torch.linspace(-8000,8000,2000), 5.12*1e-3/256)

# %%
Mt = torch.zeros([k, N_time_step+1, 3]).to(device)
Mt[:, 0, 2] = 1
torch.set_printoptions(threshold=5000)

for f in range(1, N_time_step+1):
    Mt[:, f, 0] = (Mt[:, f-1, 0] * rot[:, f-1, 0, 0]) +  (Mt[:, f-1, 1] * rot[:, f-1, 0, 1]) +  (Mt[:, f-1, 2] * rot[:, f-1, 0, 2] )
    Mt[:, f, 1] = (Mt[:, f-1, 0] * rot[:, f-1, 1, 0]) +  (Mt[:, f-1, 1] * rot[:, f-1, 1, 1]) +  (Mt[:, f-1, 2] * rot[:, f-1, 1, 2] )
    Mt[:, f, 2] = (Mt[:, f-1, 0] * rot[:, f-1, 2, 0]) +  (Mt[:, f-1, 1] * rot[:, f-1, 2, 1]) +  (Mt[:, f-1, 2] * rot[:, f-1, 2, 2])

D = Mt[:, -1, :].squeeze().reshape(-1, 1)
K = torch.mm(P, D);

# %%
# Create input vectors
preset = loadmat('./OC_input_inv_STA.mat')
w1 = np.array(preset['w1'], dtype=np.float32)
w2 = np.array(preset['w2'], dtype=np.float32)
w1 = torch.FloatTensor(w1)
w2 = torch.FloatTensor(w2)
w1 = w1.to(device)
w2 = w2.to(device)

# %%
sar_loss = []
L2_loss  = []
total_loss = []
stop = 0 
for e in range(max_N_iter):
    Mt = torch.zeros([k, N_time_step+1, 3]).to(device)
    Mt[:, 0, 2] = 1
    rot = (RF_simul(torch.transpose(w1,0,1), torch.transpose(w2,0,1), freq, T/N_time_step)).squeeze()

    for f in range(1 ,N_time_step+1):
        Mt[:, f, 0] = Mt[:, f-1, 0] * rot[:, f-1, 0, 0] +  Mt[:, f-1, 1] * rot[:, f-1, 0, 1] +  Mt[:, f-1, 2] * rot[:, f-1, 0, 2] 
        Mt[:, f, 1] = Mt[:, f-1, 0] * rot[:, f-1, 1, 0] +  Mt[:, f-1, 1] * rot[:, f-1, 1, 1] +  Mt[:, f-1, 2] * rot[:, f-1, 1, 2] 
        Mt[:, f, 2] = Mt[:, f-1, 0] * rot[:, f-1, 2, 0] +  Mt[:, f-1, 1] * rot[:, f-1, 2, 1] +  Mt[:, f-1, 2] * rot[:, f-1, 2, 2] 
    
    Mt = Mt[:, 1:, :]

    M_T = (Mt[:, -1, :]).squeeze().reshape(-1, 1)
    lambda_T = torch.transpose((torch.mm(torch.mm(torch.transpose(P, 0,1),P), M_T) - torch.mm(torch.transpose(P,0,1), K)),0,1)

    lambda_ = torch.zeros((k, N_time_step, 3)).to(device)
    lambda_[:, -1, 0] = lambda_T[:, 0:3*k:3]
    lambda_[:, -1, 1] = lambda_T[:, 1:3*k:3]
    lambda_[:, -1, 2] = lambda_T[:, 2:3*k:3]

    for b in range(N_time_step-1, 0, -1):
        lambda_[:, b-1, 0] = lambda_[:, b, 0] * rot[:, b, 0, 0] + lambda_[:, b, 1] * rot[:, b, 1, 0] + lambda_[:, b, 2] * rot[:, b, 2, 0]
        lambda_[:, b-1, 1] = lambda_[:, b, 0] * rot[:, b, 0, 1] + lambda_[:, b, 1] * rot[:, b, 1, 1] + lambda_[:, b, 2] * rot[:, b, 2, 1]
        lambda_[:, b-1, 2] = lambda_[:, b, 0] * rot[:, b, 0, 2] + lambda_[:, b, 1] * rot[:, b, 1, 2] + lambda_[:, b, 2] * rot[:, b, 2, 2]

    if e == 0 or (e+1) % 50 == 0:
        time_step = 5.12 * 1e-3 / 256 
        to_gauss = 2 * np.pi * 42.5775 * 1e+6 * time_step * 1e-4
        sar_slr = np.sum((slr/to_gauss)**2) * time_step * 1e+6

        sar_rf = torch.sum((w1**2 + w2 **2)) / (to_gauss**2) * time_step * 1e+6
        print("★★★★★★★★★★★★★★★★★★★★★★★★")
        print(f"Iteration : {e}")
        print(f"SAR of SLR : {sar_slr:.5f}")
        print(f"SAR of RF : {sar_rf:.5f}")
        print(f"SAR reduction : {(sar_slr - sar_rf)/sar_slr *100:.4f} %")
        energy = torch.sum(w1**2 + w2**2)
        M_ = (Mt[:, -1, :]).squeeze().reshape(-1, 1)
        dist = torch.matmul(P, M_) - K
        phi_d = (1/2 * (torch.mm(torch.transpose(dist, 0, 1), dist))).item()
        print(f"iteration = {e}, phi_d = {phi_d}, energy = {energy}")


    # Update rf pulse
    for u in range(N_time_step):
        M = Mt[:, u, :].squeeze().reshape(-1,1)
        lamb = lambda_[:, u, :].squeeze().reshape(-1, 1).to(device)
        w1[:, u] = w1[:, u] - mu * (torch.mm(torch.mm(torch.transpose(lamb, 0, 1), B1), M) + alpha * w1[:, u])
        #w2[:, u] = w2[:, u] - mu * (torch.mm(torch.mm(torch.transpose(lamb, 0, 1), B2), M) + alpha * w2[:, u])

    M_ = (Mt[:, -1, :]).squeeze().reshape(-1, 1)
    dist = torch.mm(P, M_) - K
    phi_d = (1/2 * (torch.mm(torch.transpose(dist, 0, 1), dist))).item()
    energy = torch.sum(w1**2 + w2**2)
    sar_loss.append(energy)
    L2_loss.append(phi_d)
    loss = phi_d + alpha * energy 
    if (e > 500) :
        if (loss > total_loss[-1]) :
            stop = stop + 1
        else : 
            stop = 0
        if stop > 5: 
            break;
        
    total_loss.append(loss)


print(f"Total time: {time.time() - start_time:.1f}")
# Out:
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 0
# SAR of SLR : 19.59590
# SAR of RF : 19.05526
# SAR reduction : 2.7589 %
# iteration = 0, phi_d = 18.92304229736328, energy = 0.27275004982948303
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 49
# SAR of SLR : 19.59590
# SAR of RF : 20.54801
# SAR reduction : -4.8587 %
# iteration = 49, phi_d = 0.005961266346275806, energy = 0.2941167950630188
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 99
# SAR of SLR : 19.59590
# SAR of RF : 20.41438
# SAR reduction : -4.1768 %
# iteration = 99, phi_d = 0.003599241841584444, energy = 0.2922040820121765
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 149
# SAR of SLR : 19.59590
# SAR of RF : 20.28045
# SAR reduction : -3.4933 %
# iteration = 149, phi_d = 0.002526490483433008, energy = 0.2902870178222656
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 199
# SAR of SLR : 19.59590
# SAR of RF : 20.13441
# SAR reduction : -2.7481 %
# iteration = 199, phi_d = 0.0013224338181316853, energy = 0.2881966233253479
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 249
# SAR of SLR : 19.59590
# SAR of RF : 20.00822
# SAR reduction : -2.1041 %
# iteration = 249, phi_d = 0.00046102661872282624, energy = 0.286390483379364
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 299
# SAR of SLR : 19.59590
# SAR of RF : 19.92521
# SAR reduction : -1.6805 %
# iteration = 299, phi_d = 0.0002366184489801526, energy = 0.2852022051811218
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 349
# SAR of SLR : 19.59590
# SAR of RF : 19.86219
# SAR reduction : -1.3589 %
# iteration = 349, phi_d = 0.0001720650470815599, energy = 0.28430020809173584
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 399
# SAR of SLR : 19.59590
# SAR of RF : 19.80303
# SAR reduction : -1.0570 %
# iteration = 399, phi_d = 0.00013767385098617524, energy = 0.28345340490341187
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 449
# SAR of SLR : 19.59590
# SAR of RF : 19.74392
# SAR reduction : -0.7554 %
# iteration = 449, phi_d = 0.0001156822036136873, energy = 0.2826072573661804
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 499
# SAR of SLR : 19.59590
# SAR of RF : 19.68440
# SAR reduction : -0.4516 %
# iteration = 499, phi_d = 0.00010001120972447097, energy = 0.28175538778305054
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 549
# SAR of SLR : 19.59590
# SAR of RF : 19.62459
# SAR reduction : -0.1464 %
# iteration = 549, phi_d = 8.782454096945003e-05, energy = 0.2808992862701416
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 599
# SAR of SLR : 19.59590
# SAR of RF : 19.56460
# SAR reduction : 0.1597 %
# iteration = 599, phi_d = 7.781282329233363e-05, energy = 0.2800406217575073
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 649
# SAR of SLR : 19.59590
# SAR of RF : 19.50451
# SAR reduction : 0.4664 %
# iteration = 649, phi_d = 6.927805225132033e-05, energy = 0.27918046712875366
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 699
# SAR of SLR : 19.59590
# SAR of RF : 19.44436
# SAR reduction : 0.7733 %
# iteration = 699, phi_d = 6.180104537634179e-05, energy = 0.2783195674419403
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 749
# SAR of SLR : 19.59590
# SAR of RF : 19.38419
# SAR reduction : 1.0804 %
# iteration = 749, phi_d = 5.522565697901882e-05, energy = 0.2774583101272583
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 799
# SAR of SLR : 19.59590
# SAR of RF : 19.32403
# SAR reduction : 1.3874 %
# iteration = 799, phi_d = 4.9404410674469545e-05, energy = 0.27659714221954346
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 849
# SAR of SLR : 19.59590
# SAR of RF : 19.26390
# SAR reduction : 1.6942 %
# iteration = 849, phi_d = 4.42667915194761e-05, energy = 0.27573642134666443
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 899
# SAR of SLR : 19.59590
# SAR of RF : 19.20382
# SAR reduction : 2.0008 %
# iteration = 899, phi_d = 3.982607813668437e-05, energy = 0.27487650513648987
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 949
# SAR of SLR : 19.59590
# SAR of RF : 19.14383
# SAR reduction : 2.3069 %
# iteration = 949, phi_d = 3.6138306313659996e-05, energy = 0.27401790022850037
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 999
# SAR of SLR : 19.59590
# SAR of RF : 19.08397
# SAR reduction : 2.6124 %
# iteration = 999, phi_d = 3.318022208986804e-05, energy = 0.27316105365753174
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 1049
# SAR of SLR : 19.59590
# SAR of RF : 19.02427
# SAR reduction : 2.9171 %
# iteration = 1049, phi_d = 3.102581831626594e-05, energy = 0.27230650186538696
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 1099
# SAR of SLR : 19.59590
# SAR of RF : 18.96477
# SAR reduction : 3.2207 %
# iteration = 1099, phi_d = 2.974691778945271e-05, energy = 0.27145490050315857
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 1149
# SAR of SLR : 19.59590
# SAR of RF : 18.90553
# SAR reduction : 3.5230 %
# iteration = 1149, phi_d = 2.940413833130151e-05, energy = 0.27060699462890625
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 1199
# SAR of SLR : 19.59590
# SAR of RF : 18.84659
# SAR reduction : 3.8238 %
# iteration = 1199, phi_d = 3.009712054335978e-05, energy = 0.26976335048675537
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 1249
# SAR of SLR : 19.59590
# SAR of RF : 18.78802
# SAR reduction : 4.1227 %
# iteration = 1249, phi_d = 3.18457605317235e-05, energy = 0.2689249515533447
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 1299
# SAR of SLR : 19.59590
# SAR of RF : 18.72987
# SAR reduction : 4.4194 %
# iteration = 1299, phi_d = 3.474757613730617e-05, energy = 0.2680925726890564
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 1349
# SAR of SLR : 19.59590
# SAR of RF : 18.67218
# SAR reduction : 4.7138 %
# iteration = 1349, phi_d = 3.886021295329556e-05, energy = 0.2672668695449829
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 1399
# SAR of SLR : 19.59590
# SAR of RF : 18.61504
# SAR reduction : 5.0054 %
# iteration = 1399, phi_d = 4.425291990628466e-05, energy = 0.2664489150047302
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 1449
# SAR of SLR : 19.59590
# SAR of RF : 18.55850
# SAR reduction : 5.2940 %
# iteration = 1449, phi_d = 5.094875450595282e-05, energy = 0.26563960313796997
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 1499
# SAR of SLR : 19.59590
# SAR of RF : 18.50262
# SAR reduction : 5.5791 %
# iteration = 1499, phi_d = 5.9003323258366436e-05, energy = 0.2648398280143738
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 1549
# SAR of SLR : 19.59590
# SAR of RF : 18.44748
# SAR reduction : 5.8605 %
# iteration = 1549, phi_d = 6.84804399497807e-05, energy = 0.26405054330825806
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 1599
# SAR of SLR : 19.59590
# SAR of RF : 18.39313
# SAR reduction : 6.1379 %
# iteration = 1599, phi_d = 7.937397458590567e-05, energy = 0.26327258348464966
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 1649
# SAR of SLR : 19.59590
# SAR of RF : 18.33965
# SAR reduction : 6.4108 %
# iteration = 1649, phi_d = 9.172850695904344e-05, energy = 0.2625070810317993
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 1699
# SAR of SLR : 19.59590
# SAR of RF : 18.28709
# SAR reduction : 6.6790 %
# iteration = 1699, phi_d = 0.00010553206084296107, energy = 0.26175475120544434
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 1749
# SAR of SLR : 19.59590
# SAR of RF : 18.23552
# SAR reduction : 6.9422 %
# iteration = 1749, phi_d = 0.00012087315553799272, energy = 0.2610166072845459
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 1799
# SAR of SLR : 19.59590
# SAR of RF : 18.18500
# SAR reduction : 7.2000 %
# iteration = 1799, phi_d = 0.0001376287400489673, energy = 0.26029348373413086
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 1849
# SAR of SLR : 19.59590
# SAR of RF : 18.13559
# SAR reduction : 7.4521 %
# iteration = 1849, phi_d = 0.0001558338844915852, energy = 0.25958627462387085
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 1899
# SAR of SLR : 19.59590
# SAR of RF : 18.08734
# SAR reduction : 7.6983 %
# iteration = 1899, phi_d = 0.00017549391486681998, energy = 0.2588956654071808
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 1949
# SAR of SLR : 19.59590
# SAR of RF : 18.04031
# SAR reduction : 7.9383 %
# iteration = 1949, phi_d = 0.00019650469766929746, energy = 0.2582224905490875
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 1999
# SAR of SLR : 19.59590
# SAR of RF : 17.99454
# SAR reduction : 8.1719 %
# iteration = 1999, phi_d = 0.0002188229700550437, energy = 0.2575673758983612
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 2049
# SAR of SLR : 19.59590
# SAR of RF : 17.95008
# SAR reduction : 8.3988 %
# iteration = 2049, phi_d = 0.00024244323140010238, energy = 0.2569309175014496
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 2099
# SAR of SLR : 19.59590
# SAR of RF : 17.90696
# SAR reduction : 8.6188 %
# iteration = 2099, phi_d = 0.00026721047470346093, energy = 0.2563137412071228
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 2149
# SAR of SLR : 19.59590
# SAR of RF : 17.86522
# SAR reduction : 8.8318 %
# iteration = 2149, phi_d = 0.00029296858701854944, energy = 0.2557162642478943
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 8399
# SAR of SLR : 19.59590
# SAR of RF : 17.10407
# SAR reduction : 12.7160 %
# iteration = 8399, phi_d = 0.0012183476937934756, energy = 0.24482154846191406
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 8449
# SAR of SLR : 19.59590
# SAR of RF : 17.10406
# SAR reduction : 12.7161 %
# iteration = 8449, phi_d = 0.0012184453662484884, energy = 0.24482128024101257
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 8499
# SAR of SLR : 19.59590
# SAR of RF : 17.10404
# SAR reduction : 12.7162 %
# iteration = 8499, phi_d = 0.0012184102088212967, energy = 0.24482107162475586
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 8549
# SAR of SLR : 19.59590
# SAR of RF : 17.10403
# SAR reduction : 12.7163 %
# iteration = 8549, phi_d = 0.0012183545622974634, energy = 0.24482089281082153
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 8599
# SAR of SLR : 19.59590
# SAR of RF : 17.10402
# SAR reduction : 12.7163 %
# iteration = 8599, phi_d = 0.001218386460095644, energy = 0.2448207139968872
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 8649
# SAR of SLR : 19.59590
# SAR of RF : 17.10400
# SAR reduction : 12.7164 %
# iteration = 8649, phi_d = 0.0012183410581201315, energy = 0.24482053518295288
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 8699
# SAR of SLR : 19.59590
# SAR of RF : 17.10399
# SAR reduction : 12.7165 %
# iteration = 8699, phi_d = 0.0012183834332972765, energy = 0.24482035636901855
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 8749
# SAR of SLR : 19.59590
# SAR of RF : 17.10398
# SAR reduction : 12.7165 %
# iteration = 8749, phi_d = 0.00121842953376472, energy = 0.24482020735740662
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 8799
# SAR of SLR : 19.59590
# SAR of RF : 17.10397
# SAR reduction : 12.7166 %
# iteration = 8799, phi_d = 0.0012184468796476722, energy = 0.24482004344463348
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 8849
# SAR of SLR : 19.59590
# SAR of RF : 17.10396
# SAR reduction : 12.7166 %
# iteration = 8849, phi_d = 0.0012184398947283626, energy = 0.24481990933418274
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 8899
# SAR of SLR : 19.59590
# SAR of RF : 17.10395
# SAR reduction : 12.7167 %
# iteration = 8899, phi_d = 0.001218338031321764, energy = 0.244819775223732
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 8949
# SAR of SLR : 19.59590
# SAR of RF : 17.10394
# SAR reduction : 12.7167 %
# iteration = 8949, phi_d = 0.0012184473453089595, energy = 0.24481964111328125
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 8999
# SAR of SLR : 19.59590
# SAR of RF : 17.10393
# SAR reduction : 12.7168 %
# iteration = 8999, phi_d = 0.0012183628277853131, energy = 0.24481947720050812
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 9049
# SAR of SLR : 19.59590
# SAR of RF : 17.10392
# SAR reduction : 12.7168 %
# iteration = 9049, phi_d = 0.0012184253428131342, energy = 0.24481938779354095
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 9099
# SAR of SLR : 19.59590
# SAR of RF : 17.10392
# SAR reduction : 12.7168 %
# iteration = 9099, phi_d = 0.0012184041552245617, energy = 0.2448192834854126
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 9149
# SAR of SLR : 19.59590
# SAR of RF : 17.10391
# SAR reduction : 12.7169 %
# iteration = 9149, phi_d = 0.0012184521183371544, energy = 0.24481913447380066
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 9199
# SAR of SLR : 19.59590
# SAR of RF : 17.10390
# SAR reduction : 12.7169 %
# iteration = 9199, phi_d = 0.001218419405631721, energy = 0.2448190152645111
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 9249
# SAR of SLR : 19.59590
# SAR of RF : 17.10389
# SAR reduction : 12.7170 %
# iteration = 9249, phi_d = 0.0012184683000668883, energy = 0.24481889605522156
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 9299
# SAR of SLR : 19.59590
# SAR of RF : 17.10388
# SAR reduction : 12.7170 %
# iteration = 9299, phi_d = 0.0012183673679828644, energy = 0.2448188066482544
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 9349
# SAR of SLR : 19.59590
# SAR of RF : 17.10387
# SAR reduction : 12.7171 %
# iteration = 9349, phi_d = 0.0012183783110231161, energy = 0.24481867253780365
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 9399
# SAR of SLR : 19.59590
# SAR of RF : 17.10387
# SAR reduction : 12.7171 %
# iteration = 9399, phi_d = 0.0012184332590550184, energy = 0.24481859803199768
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 9449
# SAR of SLR : 19.59590
# SAR of RF : 17.10386
# SAR reduction : 12.7171 %
# iteration = 9449, phi_d = 0.001218375051394105, energy = 0.24481850862503052
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 9499
# SAR of SLR : 19.59590
# SAR of RF : 17.10386
# SAR reduction : 12.7172 %
# iteration = 9499, phi_d = 0.0012183760991320014, energy = 0.24481841921806335
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 9549
# SAR of SLR : 19.59590
# SAR of RF : 17.10385
# SAR reduction : 12.7172 %
# iteration = 9549, phi_d = 0.0012183628277853131, energy = 0.2448183298110962
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 9599
# SAR of SLR : 19.59590
# SAR of RF : 17.10384
# SAR reduction : 12.7172 %
# iteration = 9599, phi_d = 0.0012184417573735118, energy = 0.24481824040412903
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 9649
# SAR of SLR : 19.59590
# SAR of RF : 17.10384
# SAR reduction : 12.7172 %
# iteration = 9649, phi_d = 0.0012184248771518469, energy = 0.24481818079948425
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 9699
# SAR of SLR : 19.59590
# SAR of RF : 17.10383
# SAR reduction : 12.7173 %
# iteration = 9699, phi_d = 0.0012183984508737922, energy = 0.2448180913925171
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 9749
# SAR of SLR : 19.59590
# SAR of RF : 17.10383
# SAR reduction : 12.7173 %
# iteration = 9749, phi_d = 0.0012183941435068846, energy = 0.24481803178787231
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 9799
# SAR of SLR : 19.59590
# SAR of RF : 17.10382
# SAR reduction : 12.7173 %
# iteration = 9799, phi_d = 0.001218438264913857, energy = 0.24481794238090515
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 9849
# SAR of SLR : 19.59590
# SAR of RF : 17.10382
# SAR reduction : 12.7173 %
# iteration = 9849, phi_d = 0.0012184130027890205, energy = 0.24481788277626038
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 9899
# SAR of SLR : 19.59590
# SAR of RF : 17.10382
# SAR reduction : 12.7174 %
# iteration = 9899, phi_d = 0.0012183412909507751, energy = 0.2448178380727768
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 9949
# SAR of SLR : 19.59590
# SAR of RF : 17.10381
# SAR reduction : 12.7174 %
# iteration = 9949, phi_d = 0.0012184367515146732, energy = 0.24481776356697083
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 9999
# SAR of SLR : 19.59590
# SAR of RF : 17.10381
# SAR reduction : 12.7174 %
# iteration = 9999, phi_d = 0.0012183429207652807, energy = 0.24481770396232605
# Total time: 3355.2

# %%
savemat("OC_result_inv8_best_STA_real.mat", {"L2loss": L2_loss, "sar_loss" : sar_loss, "w1" : w1.detach().cpu().numpy(), "w2" : w2.detach().cpu().numpy(), "total loss" : total_loss, "iteration" : e, "mu" : mu})

# %%
print(lambda_T.shape)
# Out:
# torch.Size([1, 6000])
