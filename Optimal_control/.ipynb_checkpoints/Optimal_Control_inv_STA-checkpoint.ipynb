# %%
def Bloch_simul_rot(x,y,z,T1,T2,RF,Gz,time_step,slice_thick,spatial_point,off_range):
    
    #     % units
    # % x, y, z : (spatial_point,1) for each
    # % T1, T2 : [msec]
    # % RF (2*N) : RF(1,:) is [Gauss], RF(2,:) row is angle [degree]
    # % Gz : [mT/m] (1 * N matrix) = [0.1 G/cm]
    # % time_step : pulse duration / sample points [msec]
    # % slice_thick : half of simulating thickness [m]
    # % spatial_point : number of points that are going to be simulated [#]
    # % 
    # % returns
    # % rot: (time series, 3, 3)

    T1 = T1 / 1000
    T2 = T2 / 1000

    length_RF = RF[0,:].shape[0]
    t_int = time_step * 1e-3

    # delta_omega = 2*pi*42.57747892*10^6 * (-1:2/(spatial_point-1):1).'*slice_thick*0.001*Gz;
    delta_omega = 2*np.pi*off_range.unsqueeze(1).repeat(1,256)
    RF_amp = (RF[0,:] * 2 * np.pi * 4257.747892).repeat(spatial_point, 1)
    RF_phase = (RF[1,:]).repeat(spatial_point, 1)*np.pi/180;
    alpha = t_int * torch.sqrt(RF_amp ** 2 + delta_omega **2)
    
    zeta = torch.atan2(RF_amp, delta_omega)
    theta = RF_phase
    ca = torch.cos(alpha)
    sa = torch.sin(alpha)
    cz = torch.cos(zeta)
    sz = torch.sin(zeta)
    ct = torch.cos(theta)
    st = torch.sin(theta)
    E1 = np.exp(- t_int / T1)
    E2 = np.exp(- t_int / T2)
    Mx_x_part = ct*(E2*ct*(sz**2) + cz*(E2*sa*st + E2*ca*ct*cz)) + st*(E2*ca*st - E2*ct*cz*sa)
    Mx_y_part = st*(E2*ct*(sz**2) + cz*(E2*sa*st + E2*ca*ct*cz)) - ct*(E2*ca*st - E2*ct*cz*sa)
    Mx_z_part = E2*ct*cz*sz - sz*(E2*sa*st + E2*ca*ct*cz)
    My_x_part = - ct*(- E2*st*(sz**2) + cz*(E2*ct*sa - E2*ca*cz*st)) - st*(E2*ca*ct + E2*cz*sa*st)
    My_y_part = ct*(E2*ca*ct + E2*cz*sa*st) - st*(- E2*st*(sz**2) + cz*(E2*ct*sa - E2*ca*cz*st))
    My_z_part = sz*(E2*ct*sa - E2*ca*cz*st) + E2*cz*st*sz
    Mz_x_part = ct*(E1*cz*sz - E1*ca*cz*sz) + E1*sa*st*sz
    Mz_y_part = st*(E1*cz*sz - E1*ca*cz*sz) - E1*ct*sa*sz
    Mz_z_part = E1*(cz**2) + E1*ca*(sz**2);


    rot = torch.zeros((spatial_point,length_RF,3,3))
    rot[:,:,0,0] = Mx_x_part
    rot[:,:,0,1] = Mx_y_part
    rot[:,:,0,2] = Mx_z_part
    rot[:,:,1,0] = My_x_part
    rot[:,:,1,1] = My_y_part
    rot[:,:,1,2] = My_z_part
    rot[:,:,2,0] = Mz_x_part
    rot[:,:,2,1] = Mz_y_part
    rot[:,:,2,2] = Mz_z_part
    return rot

# %%
def RF_simul(RF_pulse, RF_img, off_range, time_step):
    size = RF_pulse.shape[0]
    RF_pulse_new = torch.zeros((size,2))
    RF_pulse_new[:,0] = torch.sqrt((RF_pulse**2+RF_img**2).squeeze())
    RF_pulse_new[:,1] = torch.angle(torch.complex(RF_pulse, RF_img).squeeze())

    max_rf_amp = torch.max(RF_pulse_new[:,0]) / (2*np.pi *42.577*1e+6*time_step*1e-4)
    rr = 42.577; # MHz/T
    Gz =  40; # mT/m (fixed)
    pos = torch.abs(off_range[0] / rr / Gz); # mm
    mag = (RF_pulse_new[:,0] / torch.max(RF_pulse_new[:,0]) )* max_rf_amp
    ph = (RF_pulse_new[:,1] / np.pi)*180

    pulse = torch.cat([mag.unsqueeze(1), ph.unsqueeze(1)], 1)
    pulse = torch.transpose(pulse, 0, 1)
    gg = torch.transpose(torch.ones((RF_pulse_new.shape[0],1)), 0, 1) * Gz

    freq_shape = off_range.shape[0]
    rot = Bloch_simul_rot(np.zeros([freq_shape,1]),np.zeros([freq_shape,1]),np.ones([freq_shape,1]),1e+10,1e+10,pulse,gg,time_step * 1e+3,pos * 0.001,freq_shape,off_range).to(device)

    return rot

# %%
from os import path
import sys

import os
import time
import argparse
import gym
import numpy as np
from scipy.io import loadmat
import torch
import torch.nn as nn
from torch.optim.lr_scheduler import ReduceLROnPlateau
import matplotlib.pyplot as plt
# Select GPU
os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"] = "1"

device = 'cuda' if torch.cuda.is_available() else 'cpu'

start_time = time.time()

# Hyperparameter setting
gamma = 2 * np.pi * 42.5775 * 1e+6
N_time_step = 256
max_RF_amp = 0.2 * 1e-4 #T
max_N_iter = 10000
mu = 0.0002  #learning rate
alpha = 0.2795 # trade off between slice profile loss and sar
freq = torch.linspace(-8000, 8000, 2000) #Hz
T = 5.12*1e-3 #sec
k = freq.shape[0]
max_rad = max_RF_amp * gamma * T/N_time_step
time_step = T / N_time_step

# create B matrix
B1 = torch.zeros((3*k, 3*k)).to(device)
B2 = torch.zeros((3*k, 3*k)).to(device)

# create Projection matrix P
P = torch.zeros(3*k, 3*k).to(device)


for i in range(k) : 
    B1[i*3:(i+1)*3, i*3:(i+1)*3] = torch.from_numpy(np.array([[0,0,0], [0,0,1], [0,-1,0]]))
    B2[i*3:(i+1)*3, i*3:(i+1)*3] = torch.from_numpy(np.array([[0,0,-1], [0,0,0], [1,0,0]]))
    P[3*i+2, 3*i+2] = 1

# %%
from scipy.io import loadmat, savemat

a = loadmat('./SLR_inv_oc.mat')
slr = a['slr']
import torch
import numpy as np
rot = RF_simul(torch.from_numpy(slr), torch.zeros((256,1)).type(torch.DoubleTensor), torch.linspace(-8000,8000,2000), 5.12*1e-3/256)

# %%
Mt = torch.zeros([k, N_time_step+1, 3]).to(device)
Mt[:, 0, 2] = 1
torch.set_printoptions(threshold=5000)

for f in range(1, N_time_step+1):
    Mt[:, f, 0] = (Mt[:, f-1, 0] * rot[:, f-1, 0, 0]) +  (Mt[:, f-1, 1] * rot[:, f-1, 0, 1]) +  (Mt[:, f-1, 2] * rot[:, f-1, 0, 2] )
    Mt[:, f, 1] = (Mt[:, f-1, 0] * rot[:, f-1, 1, 0]) +  (Mt[:, f-1, 1] * rot[:, f-1, 1, 1]) +  (Mt[:, f-1, 2] * rot[:, f-1, 1, 2] )
    Mt[:, f, 2] = (Mt[:, f-1, 0] * rot[:, f-1, 2, 0]) +  (Mt[:, f-1, 1] * rot[:, f-1, 2, 1]) +  (Mt[:, f-1, 2] * rot[:, f-1, 2, 2])

D = Mt[:, -1, :].squeeze().reshape(-1, 1)
K = torch.mm(P, D);

# %%
# Create input vectors
preset = loadmat('./OC_input_inv_STA.mat')
w1 = np.array(preset['w1'], dtype=np.float32)
w2 = np.array(preset['w2'], dtype=np.float32)
w1 = torch.FloatTensor(w1)
w2 = torch.FloatTensor(w2)
w1 = w1.to(device)
w2 = w2.to(device)

# %%
a = torch.zeros(100,6000,1)
b = torch.zeros(6000,6000)
c = torch.matmul(b,a)
print(c.shape)
# Out:
# torch.Size([100, 6000, 1])

# %%
sar_loss = []
L2_loss  = []
total_loss = []
stop = 0 
for e in range(max_N_iter):
    Mt = torch.zeros([k, N_time_step+1, 3]).to(device)
    Mt[:, 0, 2] = 1
    rot = (RF_simul(torch.transpose(w1,0,1), torch.transpose(w2,0,1), freq, T/N_time_step)).squeeze()

    for f in range(1 ,N_time_step+1):
        Mt[:, f, 0] = Mt[:, f-1, 0] * rot[:, f-1, 0, 0] +  Mt[:, f-1, 1] * rot[:, f-1, 0, 1] +  Mt[:, f-1, 2] * rot[:, f-1, 0, 2] 
        Mt[:, f, 1] = Mt[:, f-1, 0] * rot[:, f-1, 1, 0] +  Mt[:, f-1, 1] * rot[:, f-1, 1, 1] +  Mt[:, f-1, 2] * rot[:, f-1, 1, 2] 
        Mt[:, f, 2] = Mt[:, f-1, 0] * rot[:, f-1, 2, 0] +  Mt[:, f-1, 1] * rot[:, f-1, 2, 1] +  Mt[:, f-1, 2] * rot[:, f-1, 2, 2] 
    
    Mt = Mt[:, 1:, :]

    M_T = (Mt[:, -1, :]).squeeze().reshape(-1, 1)
    lambda_T = torch.transpose((torch.mm(torch.mm(torch.transpose(P, 0,1),P), M_T) - torch.mm(torch.transpose(P,0,1), K)),0,1)

    lambda_ = torch.zeros((k, N_time_step, 3)).to(device)
    lambda_[:, -1, 0] = lambda_T[:, 0:3*k:3]
    lambda_[:, -1, 1] = lambda_T[:, 1:3*k:3]
    lambda_[:, -1, 2] = lambda_T[:, 2:3*k:3]

    for b in range(N_time_step-1, 0, -1):
        lambda_[:, b-1, 0] = lambda_[:, b, 0] * rot[:, b, 0, 0] + lambda_[:, b, 1] * rot[:, b, 1, 0] + lambda_[:, b, 2] * rot[:, b, 2, 0]
        lambda_[:, b-1, 1] = lambda_[:, b, 0] * rot[:, b, 0, 1] + lambda_[:, b, 1] * rot[:, b, 1, 1] + lambda_[:, b, 2] * rot[:, b, 2, 1]
        lambda_[:, b-1, 2] = lambda_[:, b, 0] * rot[:, b, 0, 2] + lambda_[:, b, 1] * rot[:, b, 1, 2] + lambda_[:, b, 2] * rot[:, b, 2, 2]

    if e == 0 or (e +1) % 50 == 0:
        time_step = 5.12 * 1e-3 / 256 
        to_gauss = 2 * np.pi * 42.5775 * 1e+6 * time_step * 1e-4
        sar_slr = np.sum((slr/to_gauss)**2) * time_step * 1e+6

        sar_rf = torch.sum((w1**2 + w2 **2)) / (to_gauss**2) * time_step * 1e+6
        print("★★★★★★★★★★★★★★★★★★★★★★★★")
        print(f"Iteration : {e}")
        print(f"SAR of SLR : {sar_slr:.5f}")
        print(f"SAR of RF : {sar_rf:.5f}")
        print(f"SAR reduction : {(sar_slr - sar_rf)/sar_slr *100:.4f} %")
        energy = torch.sum(w1**2 + w2**2)
        M_ = (Mt[:, -1, :]).squeeze().reshape(-1, 1)
        dist = torch.matmul(P, M_) - K
        phi_d = (1/2 * (torch.mm(torch.transpose(dist, 0, 1), dist))).item()
        print(f"iteration = {e}, phi_d = {phi_d}, energy = {energy}")


    # Update rf pulse
    for u in range(N_time_step):
        M = Mt[:, u, :].squeeze().reshape(-1,1)
        lamb = lambda_[:, u, :].squeeze().reshape(-1, 1).to(device)
        w1[:, u] = w1[:, u] - mu * (torch.mm(torch.mm(torch.transpose(lamb, 0, 1), B1), M) + alpha * w1[:, u])
        w2[:, u] = w2[:, u] - mu * (torch.mm(torch.mm(torch.transpose(lamb, 0, 1), B2), M) + alpha * w2[:, u])

    M_ = (Mt[:, -1, :]).squeeze().reshape(-1, 1)
    dist = torch.mm(P, M_) - K
    phi_d = (1/2 * (torch.mm(torch.transpose(dist, 0, 1), dist))).item()
    energy = torch.sum(w1**2 + w2**2)
    sar_loss.append(energy)
    L2_loss.append(phi_d)
    loss = phi_d + alpha * energy 
    if (e > 500) :
        if (loss > total_loss[-1]) :
            stop = stop + 1
        else :
            stop = 0 
        
        if(stop>5):
            break
            
    total_loss.append(loss)


print(f"Total time: {time.time() - start_time:.1f}")
# Out:
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 0
# SAR of SLR : 19.59590
# SAR of RF : 19.05526
# SAR reduction : 2.7589 %
# iteration = 0, phi_d = 18.92304229736328, energy = 0.27275004982948303
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 49
# SAR of SLR : 19.59590
# SAR of RF : 20.54801
# SAR reduction : -4.8587 %
# iteration = 49, phi_d = 0.005961272865533829, energy = 0.2941167950630188
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 99
# SAR of SLR : 19.59590
# SAR of RF : 20.41438
# SAR reduction : -4.1768 %
# iteration = 99, phi_d = 0.003599321935325861, energy = 0.2922040820121765
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 149
# SAR of SLR : 19.59590
# SAR of RF : 20.28045
# SAR reduction : -3.4934 %
# iteration = 149, phi_d = 0.002526456257328391, energy = 0.290287047624588
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 199
# SAR of SLR : 19.59590
# SAR of RF : 20.13441
# SAR reduction : -2.7481 %
# iteration = 199, phi_d = 0.001322471653111279, energy = 0.2881966233253479
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 249
# SAR of SLR : 19.59590
# SAR of RF : 20.00822
# SAR reduction : -2.1041 %
# iteration = 249, phi_d = 0.0004610110481735319, energy = 0.286390483379364
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 299
# SAR of SLR : 19.59590
# SAR of RF : 19.92521
# SAR reduction : -1.6805 %
# iteration = 299, phi_d = 0.00023662213061470538, energy = 0.2852022051811218
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 349
# SAR of SLR : 19.59590
# SAR of RF : 19.86219
# SAR reduction : -1.3589 %
# iteration = 349, phi_d = 0.00017205774202011526, energy = 0.28430020809173584
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 399
# SAR of SLR : 19.59590
# SAR of RF : 19.80303
# SAR reduction : -1.0570 %
# iteration = 399, phi_d = 0.00013767261407338083, energy = 0.2834533751010895
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 449
# SAR of SLR : 19.59590
# SAR of RF : 19.74391
# SAR reduction : -0.7553 %
# iteration = 449, phi_d = 0.00011568494664970785, energy = 0.28260722756385803
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 499
# SAR of SLR : 19.59590
# SAR of RF : 19.68440
# SAR reduction : -0.4516 %
# iteration = 499, phi_d = 0.00010000910697272047, energy = 0.28175535798072815
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 549
# SAR of SLR : 19.59590
# SAR of RF : 19.62459
# SAR reduction : -0.1464 %
# iteration = 549, phi_d = 8.782540680840611e-05, energy = 0.280899316072464
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 599
# SAR of SLR : 19.59590
# SAR of RF : 19.56460
# SAR reduction : 0.1597 %
# iteration = 599, phi_d = 7.781961176078767e-05, energy = 0.2800406217575073
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 649
# SAR of SLR : 19.59590
# SAR of RF : 19.50451
# SAR reduction : 0.4664 %
# iteration = 649, phi_d = 6.927984213689342e-05, energy = 0.27918046712875366
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 699
# SAR of SLR : 19.59590
# SAR of RF : 19.44436
# SAR reduction : 0.7733 %
# iteration = 699, phi_d = 6.181895878398791e-05, energy = 0.2783195376396179
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 749
# SAR of SLR : 19.59590
# SAR of RF : 19.38419
# SAR reduction : 1.0804 %
# iteration = 749, phi_d = 5.522874926100485e-05, energy = 0.2774583101272583
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 799
# SAR of SLR : 19.59590
# SAR of RF : 19.32403
# SAR reduction : 1.3874 %
# iteration = 799, phi_d = 4.940037615597248e-05, energy = 0.27659714221954346
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 849
# SAR of SLR : 19.59590
# SAR of RF : 19.26389
# SAR reduction : 1.6943 %
# iteration = 849, phi_d = 4.427214298630133e-05, energy = 0.27573639154434204
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 899
# SAR of SLR : 19.59590
# SAR of RF : 19.20382
# SAR reduction : 2.0008 %
# iteration = 899, phi_d = 3.98307092837058e-05, energy = 0.27487653493881226
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 949
# SAR of SLR : 19.59590
# SAR of RF : 19.14383
# SAR reduction : 2.3069 %
# iteration = 949, phi_d = 3.6134704714640975e-05, energy = 0.27401790022850037
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 999
# SAR of SLR : 19.59590
# SAR of RF : 19.08397
# SAR reduction : 2.6124 %
# iteration = 999, phi_d = 3.3176049328176305e-05, energy = 0.27316102385520935
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 1049
# SAR of SLR : 19.59590
# SAR of RF : 19.02427
# SAR reduction : 2.9171 %
# iteration = 1049, phi_d = 3.103287235717289e-05, energy = 0.27230650186538696
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 1099
# SAR of SLR : 19.59590
# SAR of RF : 18.96477
# SAR reduction : 3.2207 %
# iteration = 1099, phi_d = 2.9747883672825992e-05, energy = 0.27145490050315857
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 1149
# SAR of SLR : 19.59590
# SAR of RF : 18.90553
# SAR reduction : 3.5230 %
# iteration = 1149, phi_d = 2.9415594326565042e-05, energy = 0.27060699462890625
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 1199
# SAR of SLR : 19.59590
# SAR of RF : 18.84660
# SAR reduction : 3.8238 %
# iteration = 1199, phi_d = 3.0100847652647644e-05, energy = 0.26976338028907776
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 1249
# SAR of SLR : 19.59590
# SAR of RF : 18.78802
# SAR reduction : 4.1227 %
# iteration = 1249, phi_d = 3.184364322805777e-05, energy = 0.2689249813556671
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 7499
# SAR of SLR : 19.59590
# SAR of RF : 17.10459
# SAR reduction : 12.7134 %
# iteration = 7499, phi_d = 0.0012176221935078502, energy = 0.24482890963554382
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 7549
# SAR of SLR : 19.59590
# SAR of RF : 17.10455
# SAR reduction : 12.7136 %
# iteration = 7549, phi_d = 0.0012176017044112086, energy = 0.24482837319374084
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 7599
# SAR of SLR : 19.59590
# SAR of RF : 17.10451
# SAR reduction : 12.7138 %
# iteration = 7599, phi_d = 0.001217670040205121, energy = 0.24482783675193787
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 7649
# SAR of SLR : 19.59590
# SAR of RF : 17.10448
# SAR reduction : 12.7140 %
# iteration = 7649, phi_d = 0.0012177664320915937, energy = 0.24482733011245728
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 7699
# SAR of SLR : 19.59590
# SAR of RF : 17.10444
# SAR reduction : 12.7141 %
# iteration = 7699, phi_d = 0.001217805314809084, energy = 0.24482685327529907
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 7749
# SAR of SLR : 19.59590
# SAR of RF : 17.10441
# SAR reduction : 12.7143 %
# iteration = 7749, phi_d = 0.0012178646866232157, energy = 0.24482634663581848
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 7799
# SAR of SLR : 19.59590
# SAR of RF : 17.10438
# SAR reduction : 12.7145 %
# iteration = 7799, phi_d = 0.0012178267352283, energy = 0.24482589960098267
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 7849
# SAR of SLR : 19.59590
# SAR of RF : 17.10435
# SAR reduction : 12.7147 %
# iteration = 7849, phi_d = 0.0012179090408608317, energy = 0.24482542276382446
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 7899
# SAR of SLR : 19.59590
# SAR of RF : 17.10431
# SAR reduction : 12.7148 %
# iteration = 7899, phi_d = 0.0012179437326267362, energy = 0.24482497572898865
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 7949
# SAR of SLR : 19.59590
# SAR of RF : 17.10428
# SAR reduction : 12.7150 %
# iteration = 7949, phi_d = 0.0012180766789242625, energy = 0.24482455849647522
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 7999
# SAR of SLR : 19.59590
# SAR of RF : 17.10426
# SAR reduction : 12.7151 %
# iteration = 7999, phi_d = 0.001218086457811296, energy = 0.2448241412639618
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 8049
# SAR of SLR : 19.59590
# SAR of RF : 17.10423
# SAR reduction : 12.7152 %
# iteration = 8049, phi_d = 0.0012181531637907028, energy = 0.24482375383377075
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 8099
# SAR of SLR : 19.59590
# SAR of RF : 17.10420
# SAR reduction : 12.7154 %
# iteration = 8099, phi_d = 0.0012181956553831697, energy = 0.2448233664035797
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 8149
# SAR of SLR : 19.59590
# SAR of RF : 17.10418
# SAR reduction : 12.7155 %
# iteration = 8149, phi_d = 0.0012182282516732812, energy = 0.24482300877571106
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 8199
# SAR of SLR : 19.59590
# SAR of RF : 17.10415
# SAR reduction : 12.7156 %
# iteration = 8199, phi_d = 0.0012182483915239573, energy = 0.2448226511478424
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 8249
# SAR of SLR : 19.59590
# SAR of RF : 17.10413
# SAR reduction : 12.7158 %
# iteration = 8249, phi_d = 0.0012182805221527815, energy = 0.24482235312461853
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 8299
# SAR of SLR : 19.59590
# SAR of RF : 17.10411
# SAR reduction : 12.7159 %
# iteration = 8299, phi_d = 0.0012182533973827958, energy = 0.24482205510139465
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 8349
# SAR of SLR : 19.59590
# SAR of RF : 17.10409
# SAR reduction : 12.7159 %
# iteration = 8349, phi_d = 0.0012183415237814188, energy = 0.24482178688049316
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 8399
# SAR of SLR : 19.59590
# SAR of RF : 17.10407
# SAR reduction : 12.7160 %
# iteration = 8399, phi_d = 0.001218281453475356, energy = 0.24482150375843048
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 8449
# SAR of SLR : 19.59590
# SAR of RF : 17.10406
# SAR reduction : 12.7161 %
# iteration = 8449, phi_d = 0.0012183589860796928, energy = 0.24482128024101257
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 8499
# SAR of SLR : 19.59590
# SAR of RF : 17.10404
# SAR reduction : 12.7162 %
# iteration = 8499, phi_d = 0.0012184793595224619, energy = 0.24482104182243347
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 8549
# SAR of SLR : 19.59590
# SAR of RF : 17.10402
# SAR reduction : 12.7163 %
# iteration = 8549, phi_d = 0.0012183825019747019, energy = 0.24482083320617676
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 8599
# SAR of SLR : 19.59590
# SAR of RF : 17.10401
# SAR reduction : 12.7164 %
# iteration = 8599, phi_d = 0.0012184195220470428, energy = 0.24482065439224243
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 8649
# SAR of SLR : 19.59590
# SAR of RF : 17.10400
# SAR reduction : 12.7164 %
# iteration = 8649, phi_d = 0.0012184373335912824, energy = 0.2448204606771469
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 8699
# SAR of SLR : 19.59590
# SAR of RF : 17.10399
# SAR reduction : 12.7165 %
# iteration = 8699, phi_d = 0.0012183742364868522, energy = 0.24482029676437378
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 8749
# SAR of SLR : 19.59590
# SAR of RF : 17.10398
# SAR reduction : 12.7165 %
# iteration = 8749, phi_d = 0.001218434888869524, energy = 0.24482016265392303
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 8799
# SAR of SLR : 19.59590
# SAR of RF : 17.10397
# SAR reduction : 12.7166 %
# iteration = 8799, phi_d = 0.0012184747029095888, energy = 0.2448200285434723
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 8849
# SAR of SLR : 19.59590
# SAR of RF : 17.10396
# SAR reduction : 12.7166 %
# iteration = 8849, phi_d = 0.0012184896040707827, energy = 0.24481990933418274
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 8899
# SAR of SLR : 19.59590
# SAR of RF : 17.10395
# SAR reduction : 12.7167 %
# iteration = 8899, phi_d = 0.0012183719081804156, energy = 0.2448197603225708
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 8949
# SAR of SLR : 19.59590
# SAR of RF : 17.10394
# SAR reduction : 12.7167 %
# iteration = 8949, phi_d = 0.0012184337247163057, energy = 0.24481962621212006
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 8999
# SAR of SLR : 19.59590
# SAR of RF : 17.10393
# SAR reduction : 12.7168 %
# iteration = 8999, phi_d = 0.0012183949584141374, energy = 0.2448194921016693
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 9049
# SAR of SLR : 19.59590
# SAR of RF : 17.10392
# SAR reduction : 12.7168 %
# iteration = 9049, phi_d = 0.0012183875078335404, energy = 0.24481937289237976
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 9099
# SAR of SLR : 19.59590
# SAR of RF : 17.10392
# SAR reduction : 12.7168 %
# iteration = 9099, phi_d = 0.001218415447510779, energy = 0.2448192685842514
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 9149
# SAR of SLR : 19.59590
# SAR of RF : 17.10391
# SAR reduction : 12.7169 %
# iteration = 9149, phi_d = 0.001218478661030531, energy = 0.24481916427612305
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 9199
# SAR of SLR : 19.59590
# SAR of RF : 17.10390
# SAR reduction : 12.7169 %
# iteration = 9199, phi_d = 0.00121832056902349, energy = 0.2448190450668335
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 9249
# SAR of SLR : 19.59590
# SAR of RF : 17.10389
# SAR reduction : 12.7170 %
# iteration = 9249, phi_d = 0.0012183827348053455, energy = 0.24481891095638275
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 9299
# SAR of SLR : 19.59590
# SAR of RF : 17.10388
# SAR reduction : 12.7170 %
# iteration = 9299, phi_d = 0.0012183659709990025, energy = 0.2448188066482544
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 9349
# SAR of SLR : 19.59590
# SAR of RF : 17.10388
# SAR reduction : 12.7170 %
# iteration = 9349, phi_d = 0.0012184123042970896, energy = 0.24481868743896484
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 9399
# SAR of SLR : 19.59590
# SAR of RF : 17.10387
# SAR reduction : 12.7171 %
# iteration = 9399, phi_d = 0.0012184297665953636, energy = 0.24481862783432007
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 9449
# SAR of SLR : 19.59590
# SAR of RF : 17.10386
# SAR reduction : 12.7171 %
# iteration = 9449, phi_d = 0.0012183364015072584, energy = 0.2448185384273529
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 9499
# SAR of SLR : 19.59590
# SAR of RF : 17.10386
# SAR reduction : 12.7172 %
# iteration = 9499, phi_d = 0.0012183244107291102, energy = 0.24481841921806335
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 9549
# SAR of SLR : 19.59590
# SAR of RF : 17.10385
# SAR reduction : 12.7172 %
# iteration = 9549, phi_d = 0.00121838110499084, energy = 0.2448183298110962
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 9599
# SAR of SLR : 19.59590
# SAR of RF : 17.10384
# SAR reduction : 12.7172 %
# iteration = 9599, phi_d = 0.0012184164952486753, energy = 0.24481825530529022
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 9649
# SAR of SLR : 19.59590
# SAR of RF : 17.10384
# SAR reduction : 12.7172 %
# iteration = 9649, phi_d = 0.0012183678336441517, energy = 0.24481818079948425
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 9699
# SAR of SLR : 19.59590
# SAR of RF : 17.10383
# SAR reduction : 12.7173 %
# iteration = 9699, phi_d = 0.0012183701619505882, energy = 0.2448180913925171
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 9749
# SAR of SLR : 19.59590
# SAR of RF : 17.10383
# SAR reduction : 12.7173 %
# iteration = 9749, phi_d = 0.0012183807557448745, energy = 0.24481801688671112
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 9799
# SAR of SLR : 19.59590
# SAR of RF : 17.10382
# SAR reduction : 12.7173 %
# iteration = 9799, phi_d = 0.0012184435036033392, energy = 0.24481797218322754
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 9849
# SAR of SLR : 19.59590
# SAR of RF : 17.10382
# SAR reduction : 12.7173 %
# iteration = 9849, phi_d = 0.0012184256920590997, energy = 0.24481789767742157
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 9899
# SAR of SLR : 19.59590
# SAR of RF : 17.10382
# SAR reduction : 12.7174 %
# iteration = 9899, phi_d = 0.0012184074148535728, energy = 0.2448178231716156
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 9949
# SAR of SLR : 19.59590
# SAR of RF : 17.10381
# SAR reduction : 12.7174 %
# iteration = 9949, phi_d = 0.001218434888869524, energy = 0.24481776356697083
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 9999
# SAR of SLR : 19.59590
# SAR of RF : 17.10381
# SAR reduction : 12.7174 %
# iteration = 9999, phi_d = 0.0012183631770312786, energy = 0.24481771886348724
# Total time: 4338.4

# %%
savemat("OC_result_inv8_STA.mat", {"L2loss": L2_loss, "sar_loss" : sar_loss, "w1" : w1.detach().cpu().numpy(), "w2" : w2.detach().cpu().numpy(), "total loss" : total_loss, "iteration" : e, "mu" : mu})
