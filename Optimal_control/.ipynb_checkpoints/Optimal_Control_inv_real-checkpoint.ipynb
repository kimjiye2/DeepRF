# %%
def Bloch_simul_rot(x,y,z,T1,T2,RF,Gz,time_step,slice_thick,spatial_point,off_range):
    
    #     % units
    # % x, y, z : (spatial_point,1) for each
    # % T1, T2 : [msec]
    # % RF (2*N) : RF(1,:) is [Gauss], RF(2,:) row is angle [degree]
    # % Gz : [mT/m] (1 * N matrix) = [0.1 G/cm]
    # % time_step : pulse duration / sample points [msec]
    # % slice_thick : half of simulating thickness [m]
    # % spatial_point : number of points that are going to be simulated [#]
    # % 
    # % returns
    # % rot: (time series, 3, 3)

    T1 = T1 / 1000
    T2 = T2 / 1000

    length_RF = RF[0,:].shape[0]
    t_int = time_step * 1e-3

    # delta_omega = 2*pi*42.57747892*10^6 * (-1:2/(spatial_point-1):1).'*slice_thick*0.001*Gz;
    delta_omega = 2*np.pi*off_range.unsqueeze(1).repeat(1,256)
    RF_amp = (RF[0,:] * 2 * np.pi * 4257.747892).repeat(spatial_point, 1)
    RF_phase = (RF[1,:]).repeat(spatial_point, 1)*np.pi/180;
    alpha = t_int * torch.sqrt(RF_amp ** 2 + delta_omega **2)
    
    zeta = torch.atan2(RF_amp, delta_omega)
    theta = RF_phase
    ca = torch.cos(alpha)
    sa = torch.sin(alpha)
    cz = torch.cos(zeta)
    sz = torch.sin(zeta)
    ct = torch.cos(theta)
    st = torch.sin(theta)
    E1 = np.exp(- t_int / T1)
    E2 = np.exp(- t_int / T2)
    Mx_x_part = ct*(E2*ct*(sz**2) + cz*(E2*sa*st + E2*ca*ct*cz)) + st*(E2*ca*st - E2*ct*cz*sa)
    Mx_y_part = st*(E2*ct*(sz**2) + cz*(E2*sa*st + E2*ca*ct*cz)) - ct*(E2*ca*st - E2*ct*cz*sa)
    Mx_z_part = E2*ct*cz*sz - sz*(E2*sa*st + E2*ca*ct*cz)
    My_x_part = - ct*(- E2*st*(sz**2) + cz*(E2*ct*sa - E2*ca*cz*st)) - st*(E2*ca*ct + E2*cz*sa*st)
    My_y_part = ct*(E2*ca*ct + E2*cz*sa*st) - st*(- E2*st*(sz**2) + cz*(E2*ct*sa - E2*ca*cz*st))
    My_z_part = sz*(E2*ct*sa - E2*ca*cz*st) + E2*cz*st*sz
    Mz_x_part = ct*(E1*cz*sz - E1*ca*cz*sz) + E1*sa*st*sz
    Mz_y_part = st*(E1*cz*sz - E1*ca*cz*sz) - E1*ct*sa*sz
    Mz_z_part = E1*(cz**2) + E1*ca*(sz**2);


    rot = torch.zeros((spatial_point,length_RF,3,3))
    rot[:,:,0,0] = Mx_x_part
    rot[:,:,0,1] = Mx_y_part
    rot[:,:,0,2] = Mx_z_part
    rot[:,:,1,0] = My_x_part
    rot[:,:,1,1] = My_y_part
    rot[:,:,1,2] = My_z_part
    rot[:,:,2,0] = Mz_x_part
    rot[:,:,2,1] = Mz_y_part
    rot[:,:,2,2] = Mz_z_part
    return rot

# %%
def RF_simul(RF_pulse, RF_img, off_range, time_step):
    size = RF_pulse.shape[0]
    RF_pulse_new = torch.zeros((size,2))
    RF_pulse_new[:,0] = torch.sqrt((RF_pulse**2+RF_img**2).squeeze())
    RF_pulse_new[:,1] = torch.angle(torch.complex(RF_pulse, RF_img).squeeze())

    max_rf_amp = torch.max(RF_pulse_new[:,0]) / (2*np.pi *42.577*1e+6*time_step*1e-4)
    rr = 42.577; # MHz/T
    Gz =  40; # mT/m (fixed)
    pos = torch.abs(off_range[0] / rr / Gz); # mm
    mag = (RF_pulse_new[:,0] / torch.max(RF_pulse_new[:,0]) )* max_rf_amp
    ph = (RF_pulse_new[:,1] / np.pi)*180

    pulse = torch.cat([mag.unsqueeze(1), ph.unsqueeze(1)], 1)
    pulse = torch.transpose(pulse, 0, 1)
    gg = torch.transpose(torch.ones((RF_pulse_new.shape[0],1)), 0, 1) * Gz

    freq_shape = off_range.shape[0]
    rot = Bloch_simul_rot(np.zeros([freq_shape,1]),np.zeros([freq_shape,1]),np.ones([freq_shape,1]),1e+10,1e+10,pulse,gg,time_step * 1e+3,pos * 0.001,freq_shape,off_range).to(device)

    return rot

# %%
from os import path
import sys

import os
import time
import argparse
import gym
import numpy as np
from scipy.io import loadmat
import torch
import torch.nn as nn
from torch.optim.lr_scheduler import ReduceLROnPlateau
import matplotlib.pyplot as plt
# Select GPU
os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"] = "1"

device = 'cuda' if torch.cuda.is_available() else 'cpu'

start_time = time.time()

# Hyperparameter setting
gamma = 2 * np.pi * 42.5775 * 1e+6
N_time_step = 256
max_RF_amp = 0.2 * 1e-4 #T
max_N_iter = 5000
mu = 0.00015  #learning rate
alpha = 0.2795 # trade off between slice profile loss and sar
freq = torch.linspace(-8000, 8000, 2000) #Hz
T = 5.12*1e-3 #sec
k = freq.shape[0]
max_rad = max_RF_amp * gamma * T/N_time_step
time_step = T / N_time_step

# create B matrix
B1 = torch.zeros((3*k, 3*k)).to(device)
B2 = torch.zeros((3*k, 3*k)).to(device)

# create Projection matrix P
P = torch.zeros(3*k, 3*k).to(device)


for i in range(k) : 
    B1[i*3:(i+1)*3, i*3:(i+1)*3] = torch.from_numpy(np.array([[0,0,0], [0,0,1], [0,-1,0]]))
    B2[i*3:(i+1)*3, i*3:(i+1)*3] = torch.from_numpy(np.array([[0,0,-1], [0,0,0], [1,0,0]]))
    P[3*i+2, 3*i+2] = 1

# %%
from scipy.io import loadmat, savemat

a = loadmat('./SLR_inv_oc.mat')
slr = a['slr']
import torch
import numpy as np
rot = RF_simul(torch.from_numpy(slr), torch.zeros((256,1)).type(torch.DoubleTensor), torch.linspace(-8000,8000,2000), 5.12*1e-3/256)

# %%
Mt = torch.zeros([k, N_time_step+1, 3]).to(device)
Mt[:, 0, 2] = 1
torch.set_printoptions(threshold=5000)

for f in range(1, N_time_step+1):
    Mt[:, f, 0] = (Mt[:, f-1, 0] * rot[:, f-1, 0, 0]) +  (Mt[:, f-1, 1] * rot[:, f-1, 0, 1]) +  (Mt[:, f-1, 2] * rot[:, f-1, 0, 2] )
    Mt[:, f, 1] = (Mt[:, f-1, 0] * rot[:, f-1, 1, 0]) +  (Mt[:, f-1, 1] * rot[:, f-1, 1, 1]) +  (Mt[:, f-1, 2] * rot[:, f-1, 1, 2] )
    Mt[:, f, 2] = (Mt[:, f-1, 0] * rot[:, f-1, 2, 0]) +  (Mt[:, f-1, 1] * rot[:, f-1, 2, 1]) +  (Mt[:, f-1, 2] * rot[:, f-1, 2, 2])

D = Mt[:, -1, :].squeeze().reshape(-1, 1)
K = torch.mm(P, D);

# %%
# Create input vectors
preset = loadmat('./OC_input_inv_STA.mat')
w1 = np.array(preset['w1'], dtype=np.float32)
w2 = np.array(preset['w2'], dtype=np.float32)
w1 = torch.FloatTensor(w1)
w2 = torch.FloatTensor(w2)
w1 = w1.to(device)
w2 = w2.to(device)

# %%
sar_loss = []
L2_loss  = []
total_loss = []

for e in range(max_N_iter):
    Mt = torch.zeros([k, N_time_step+1, 3]).to(device)
    Mt[:, 0, 2] = 1
    rot = (RF_simul(torch.transpose(w1,0,1), torch.transpose(w2,0,1), freq, T/N_time_step)).squeeze()

    for f in range(1 ,N_time_step+1):
        Mt[:, f, 0] = Mt[:, f-1, 0] * rot[:, f-1, 0, 0] +  Mt[:, f-1, 1] * rot[:, f-1, 0, 1] +  Mt[:, f-1, 2] * rot[:, f-1, 0, 2] 
        Mt[:, f, 1] = Mt[:, f-1, 0] * rot[:, f-1, 1, 0] +  Mt[:, f-1, 1] * rot[:, f-1, 1, 1] +  Mt[:, f-1, 2] * rot[:, f-1, 1, 2] 
        Mt[:, f, 2] = Mt[:, f-1, 0] * rot[:, f-1, 2, 0] +  Mt[:, f-1, 1] * rot[:, f-1, 2, 1] +  Mt[:, f-1, 2] * rot[:, f-1, 2, 2] 
    
    Mt = Mt[:, 1:, :]

    M_T = (Mt[:, -1, :]).squeeze().reshape(-1, 1)
    lambda_T = torch.transpose((torch.mm(torch.mm(torch.transpose(P, 0,1),P), M_T) - torch.mm(torch.transpose(P,0,1), K)),0,1)

    lambda_ = torch.zeros((k, N_time_step, 3)).to(device)
    lambda_[:, -1, 0] = lambda_T[:, 0:3*k:3]
    lambda_[:, -1, 1] = lambda_T[:, 1:3*k:3]
    lambda_[:, -1, 2] = lambda_T[:, 2:3*k:3]

    for b in range(N_time_step-1, 0, -1):
        lambda_[:, b-1, 0] = lambda_[:, b, 0] * rot[:, b, 0, 0] + lambda_[:, b, 1] * rot[:, b, 1, 0] + lambda_[:, b, 2] * rot[:, b, 2, 0]
        lambda_[:, b-1, 1] = lambda_[:, b, 0] * rot[:, b, 0, 1] + lambda_[:, b, 1] * rot[:, b, 1, 1] + lambda_[:, b, 2] * rot[:, b, 2, 1]
        lambda_[:, b-1, 2] = lambda_[:, b, 0] * rot[:, b, 0, 2] + lambda_[:, b, 1] * rot[:, b, 1, 2] + lambda_[:, b, 2] * rot[:, b, 2, 2]

    if (e) % 30 == 0:
        time_step = 5.12 * 1e-3 / 256 
        to_gauss = 2 * np.pi * 42.5775 * 1e+6 * time_step * 1e-4
        sar_slr = np.sum((slr/to_gauss)**2) * time_step * 1e+6

        sar_rf = torch.sum((w1**2 + w2 **2)) / (to_gauss**2) * time_step * 1e+6
        print("★★★★★★★★★★★★★★★★★★★★★★★★")
        print(f"Iteration : {e}")
        print(f"SAR of SLR : {sar_slr:.5f}")
        print(f"SAR of RF : {sar_rf:.5f}")
        print(f"SAR reduction : {(sar_slr - sar_rf)/sar_slr *100:.4f} %")
        energy = torch.sum(w1**2 + w2**2)
        M_ = (Mt[:, -1, :]).squeeze().reshape(-1, 1)
        dist = torch.matmul(P, M_) - K
        phi_d = (1/2 * (torch.mm(torch.transpose(dist, 0, 1), dist))).item()
        print(f"iteration = {e}, phi_d = {phi_d}, energy = {energy}")


    # Update rf pulse
    for u in range(N_time_step):
        M = Mt[:, u, :].squeeze().reshape(-1,1)
        lamb = lambda_[:, u, :].squeeze().reshape(-1, 1).to(device)
        w1[:, u] = w1[:, u] - mu * (torch.mm(torch.mm(torch.transpose(lamb, 0, 1), B1), M) + alpha * w1[:, u])
        #w2[:, u] = w2[:, u] - mu * (torch.mm(torch.mm(torch.transpose(lamb, 0, 1), B2), M) + alpha * w2[:, u])

    M_ = (Mt[:, -1, :]).squeeze().reshape(-1, 1)
    dist = torch.mm(P, M_) - K
    phi_d = (1/2 * (torch.mm(torch.transpose(dist, 0, 1), dist))).item()
    energy = torch.sum(w1**2 + w2**2)
    sar_loss.append(energy)
    L2_loss.append(phi_d)
    loss = phi_d + alpha * energy 
    if (e > 500) :
        if (loss > total_loss[-1]) :
            break
    total_loss.append(loss)


print(f"Total time: {time.time() - start_time:.1f}")
# Out:
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 0
# SAR of SLR : 19.59590
# SAR of RF : 19.05526
# SAR reduction : 2.7589 %
# iteration = 0, phi_d = 18.92304229736328, energy = 0.27275004982948303
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 30
# SAR of SLR : 19.59590
# SAR of RF : 20.69562
# SAR reduction : -5.6120 %
# iteration = 30, phi_d = 0.014026605524122715, energy = 0.29622966051101685
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 60
# SAR of SLR : 19.59590
# SAR of RF : 20.60730
# SAR reduction : -5.1613 %
# iteration = 60, phi_d = 0.006514052394777536, energy = 0.2949654459953308
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 90
# SAR of SLR : 19.59590
# SAR of RF : 20.54689
# SAR reduction : -4.8530 %
# iteration = 90, phi_d = 0.004710513167083263, energy = 0.2941007614135742
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 120
# SAR of SLR : 19.59590
# SAR of RF : 20.49272
# SAR reduction : -4.5766 %
# iteration = 120, phi_d = 0.003909674938768148, energy = 0.29332542419433594
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 150
# SAR of SLR : 19.59590
# SAR of RF : 20.43900
# SAR reduction : -4.3024 %
# iteration = 150, phi_d = 0.0034047660883516073, energy = 0.29255643486976624
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 180
# SAR of SLR : 19.59590
# SAR of RF : 20.38320
# SAR reduction : -4.0177 %
# iteration = 180, phi_d = 0.0029882886447012424, energy = 0.2917577624320984
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 210
# SAR of SLR : 19.59590
# SAR of RF : 20.32401
# SAR reduction : -3.7156 %
# iteration = 210, phi_d = 0.0025670635513961315, energy = 0.2909104824066162
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 240
# SAR of SLR : 19.59590
# SAR of RF : 20.26116
# SAR reduction : -3.3949 %
# iteration = 240, phi_d = 0.0020898887887597084, energy = 0.29001086950302124
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 270
# SAR of SLR : 19.59590
# SAR of RF : 20.19610
# SAR reduction : -3.0629 %
# iteration = 270, phi_d = 0.0015543261542916298, energy = 0.2890796363353729
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 300
# SAR of SLR : 19.59590
# SAR of RF : 20.13257
# SAR reduction : -2.7387 %
# iteration = 300, phi_d = 0.001031481078825891, energy = 0.28817039728164673
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 330
# SAR of SLR : 19.59590
# SAR of RF : 20.07553
# SAR reduction : -2.4477 %
# iteration = 330, phi_d = 0.0006325445137917995, energy = 0.2873539626598358
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 360
# SAR of SLR : 19.59590
# SAR of RF : 20.02802
# SAR reduction : -2.2052 %
# iteration = 360, phi_d = 0.00040000962326303124, energy = 0.286673903465271
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 390
# SAR of SLR : 19.59590
# SAR of RF : 19.98945
# SAR reduction : -2.0084 %
# iteration = 390, phi_d = 0.00028570197173394263, energy = 0.28612184524536133
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 420
# SAR of SLR : 19.59590
# SAR of RF : 19.95708
# SAR reduction : -1.8432 %
# iteration = 420, phi_d = 0.00022802100284025073, energy = 0.28565847873687744
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 450
# SAR of SLR : 19.59590
# SAR of RF : 19.92820
# SAR reduction : -1.6958 %
# iteration = 450, phi_d = 0.00019355992844793946, energy = 0.28524500131607056
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 480
# SAR of SLR : 19.59590
# SAR of RF : 19.90098
# SAR reduction : -1.5569 %
# iteration = 480, phi_d = 0.00016953598242253065, energy = 0.2848554849624634
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 510
# SAR of SLR : 19.59590
# SAR of RF : 19.87445
# SAR reduction : -1.4215 %
# iteration = 510, phi_d = 0.00015135690046008676, energy = 0.2844756841659546
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 540
# SAR of SLR : 19.59590
# SAR of RF : 19.84812
# SAR reduction : -1.2871 %
# iteration = 540, phi_d = 0.00013707636389881372, energy = 0.284098744392395
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 570
# SAR of SLR : 19.59590
# SAR of RF : 19.82177
# SAR reduction : -1.1526 %
# iteration = 570, phi_d = 0.0001255879324162379, energy = 0.2837216258049011
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 600
# SAR of SLR : 19.59590
# SAR of RF : 19.79534
# SAR reduction : -1.0178 %
# iteration = 600, phi_d = 0.0001161037725978531, energy = 0.2833433151245117
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 630
# SAR of SLR : 19.59590
# SAR of RF : 19.76880
# SAR reduction : -0.8824 %
# iteration = 630, phi_d = 0.00010809046943904832, energy = 0.28296351432800293
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 660
# SAR of SLR : 19.59590
# SAR of RF : 19.74217
# SAR reduction : -0.7465 %
# iteration = 660, phi_d = 0.00010117649799212813, energy = 0.28258228302001953
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 690
# SAR of SLR : 19.59590
# SAR of RF : 19.71545
# SAR reduction : -0.6101 %
# iteration = 690, phi_d = 9.508912626188248e-05, energy = 0.2821998596191406
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 720
# SAR of SLR : 19.59590
# SAR of RF : 19.68867
# SAR reduction : -0.4734 %
# iteration = 720, phi_d = 8.966307359514758e-05, energy = 0.2818164527416229
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 750
# SAR of SLR : 19.59590
# SAR of RF : 19.66182
# SAR reduction : -0.3364 %
# iteration = 750, phi_d = 8.474584319628775e-05, energy = 0.28143221139907837
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 780
# SAR of SLR : 19.59590
# SAR of RF : 19.63494
# SAR reduction : -0.1992 %
# iteration = 780, phi_d = 8.024086855584756e-05, energy = 0.28104737401008606
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 810
# SAR of SLR : 19.59590
# SAR of RF : 19.60801
# SAR reduction : -0.0618 %
# iteration = 810, phi_d = 7.607557199662551e-05, energy = 0.28066200017929077
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 840
# SAR of SLR : 19.59590
# SAR of RF : 19.58106
# SAR reduction : 0.0757 %
# iteration = 840, phi_d = 7.219419057946652e-05, energy = 0.28027623891830444
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 870
# SAR of SLR : 19.59590
# SAR of RF : 19.55408
# SAR reduction : 0.2134 %
# iteration = 870, phi_d = 6.855330138932914e-05, energy = 0.27989012002944946
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 900
# SAR of SLR : 19.59590
# SAR of RF : 19.52709
# SAR reduction : 0.3511 %
# iteration = 900, phi_d = 6.510903767775744e-05, energy = 0.279503732919693
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 930
# SAR of SLR : 19.59590
# SAR of RF : 19.50008
# SAR reduction : 0.4889 %
# iteration = 930, phi_d = 6.188827683217824e-05, energy = 0.2791171669960022
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 960
# SAR of SLR : 19.59590
# SAR of RF : 19.47306
# SAR reduction : 0.6268 %
# iteration = 960, phi_d = 5.883501216885634e-05, energy = 0.2787303924560547
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 990
# SAR of SLR : 19.59590
# SAR of RF : 19.44604
# SAR reduction : 0.7647 %
# iteration = 990, phi_d = 5.591019362327643e-05, energy = 0.2783435583114624
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 1020
# SAR of SLR : 19.59590
# SAR of RF : 19.41900
# SAR reduction : 0.9027 %
# iteration = 1020, phi_d = 5.3148069127928466e-05, energy = 0.27795660495758057
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 1050
# SAR of SLR : 19.59590
# SAR of RF : 19.39197
# SAR reduction : 1.0407 %
# iteration = 1050, phi_d = 5.0531984015833586e-05, energy = 0.27756959199905396
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 1080
# SAR of SLR : 19.59590
# SAR of RF : 19.36493
# SAR reduction : 1.1786 %
# iteration = 1080, phi_d = 4.8049634642666206e-05, energy = 0.2771826386451721
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 1110
# SAR of SLR : 19.59590
# SAR of RF : 19.33790
# SAR reduction : 1.3166 %
# iteration = 1110, phi_d = 4.5690772822126746e-05, energy = 0.2767956852912903
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 1140
# SAR of SLR : 19.59590
# SAR of RF : 19.31087
# SAR reduction : 1.4545 %
# iteration = 1140, phi_d = 4.3468524381751195e-05, energy = 0.2764087915420532
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 1170
# SAR of SLR : 19.59590
# SAR of RF : 19.28385
# SAR reduction : 1.5924 %
# iteration = 1170, phi_d = 4.138395161135122e-05, energy = 0.2760220170021057
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 1200
# SAR of SLR : 19.59590
# SAR of RF : 19.25683
# SAR reduction : 1.7303 %
# iteration = 1200, phi_d = 3.941573595511727e-05, energy = 0.27563533186912537
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 1230
# SAR of SLR : 19.59590
# SAR of RF : 19.22983
# SAR reduction : 1.8681 %
# iteration = 1230, phi_d = 3.759287574212067e-05, energy = 0.27524882555007935
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 1260
# SAR of SLR : 19.59590
# SAR of RF : 19.20284
# SAR reduction : 2.0058 %
# iteration = 1260, phi_d = 3.589030166040175e-05, energy = 0.2748625874519348
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 1290
# SAR of SLR : 19.59590
# SAR of RF : 19.17588
# SAR reduction : 2.1434 %
# iteration = 1290, phi_d = 3.433587698964402e-05, energy = 0.2744765877723694
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 1320
# SAR of SLR : 19.59590
# SAR of RF : 19.14893
# SAR reduction : 2.2809 %
# iteration = 1320, phi_d = 3.292800101917237e-05, energy = 0.27409088611602783
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 1350
# SAR of SLR : 19.59590
# SAR of RF : 19.12201
# SAR reduction : 2.4183 %
# iteration = 1350, phi_d = 3.165974703733809e-05, energy = 0.27370551228523254
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 1380
# SAR of SLR : 19.59590
# SAR of RF : 19.09511
# SAR reduction : 2.5556 %
# iteration = 1380, phi_d = 3.055403794860467e-05, energy = 0.2733205556869507
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 1410
# SAR of SLR : 19.59590
# SAR of RF : 19.06825
# SAR reduction : 2.6926 %
# iteration = 1410, phi_d = 2.96046600851696e-05, energy = 0.27293604612350464
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 1440
# SAR of SLR : 19.59590
# SAR of RF : 19.04142
# SAR reduction : 2.8295 %
# iteration = 1440, phi_d = 2.881687760236673e-05, energy = 0.2725520133972168
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 1470
# SAR of SLR : 19.59590
# SAR of RF : 19.01463
# SAR reduction : 2.9662 %
# iteration = 1470, phi_d = 2.819685141730588e-05, energy = 0.2721685767173767
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 1500
# SAR of SLR : 19.59590
# SAR of RF : 18.98789
# SAR reduction : 3.1027 %
# iteration = 1500, phi_d = 2.775989196379669e-05, energy = 0.27178579568862915
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 1530
# SAR of SLR : 19.59590
# SAR of RF : 18.96119
# SAR reduction : 3.2390 %
# iteration = 1530, phi_d = 2.7498183044372126e-05, energy = 0.27140361070632935
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 1560
# SAR of SLR : 19.59590
# SAR of RF : 18.93454
# SAR reduction : 3.3750 %
# iteration = 1560, phi_d = 2.743220466072671e-05, energy = 0.2710222005844116
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 1590
# SAR of SLR : 19.59590
# SAR of RF : 18.90796
# SAR reduction : 3.5106 %
# iteration = 1590, phi_d = 2.755676905508153e-05, energy = 0.2706416845321655
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 1620
# SAR of SLR : 19.59590
# SAR of RF : 18.88144
# SAR reduction : 3.6460 %
# iteration = 1620, phi_d = 2.787536141113378e-05, energy = 0.2702620327472687
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 1650
# SAR of SLR : 19.59590
# SAR of RF : 18.85497
# SAR reduction : 3.7810 %
# iteration = 1650, phi_d = 2.83975441561779e-05, energy = 0.26988327503204346
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 1680
# SAR of SLR : 19.59590
# SAR of RF : 18.82859
# SAR reduction : 3.9156 %
# iteration = 1680, phi_d = 2.9142540370230563e-05, energy = 0.2695056200027466
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 1710
# SAR of SLR : 19.59590
# SAR of RF : 18.80227
# SAR reduction : 4.0499 %
# iteration = 1710, phi_d = 3.0109637009445578e-05, energy = 0.2691289782524109
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 1740
# SAR of SLR : 19.59590
# SAR of RF : 18.77604
# SAR reduction : 4.1838 %
# iteration = 1740, phi_d = 3.1293981010094285e-05, energy = 0.2687534689903259
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 1770
# SAR of SLR : 19.59590
# SAR of RF : 18.74990
# SAR reduction : 4.3172 %
# iteration = 1770, phi_d = 3.269899025326595e-05, energy = 0.268379271030426
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 1800
# SAR of SLR : 19.59590
# SAR of RF : 18.72385
# SAR reduction : 4.4502 %
# iteration = 1800, phi_d = 3.434208338148892e-05, energy = 0.26800641417503357
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 1830
# SAR of SLR : 19.59590
# SAR of RF : 18.69790
# SAR reduction : 4.5826 %
# iteration = 1830, phi_d = 3.623536031227559e-05, energy = 0.26763492822647095
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 1860
# SAR of SLR : 19.59590
# SAR of RF : 18.67205
# SAR reduction : 4.7145 %
# iteration = 1860, phi_d = 3.83605292881839e-05, energy = 0.2672649621963501
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 1890
# SAR of SLR : 19.59590
# SAR of RF : 18.64631
# SAR reduction : 4.8459 %
# iteration = 1890, phi_d = 4.0728064050199464e-05, energy = 0.26689648628234863
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 1920
# SAR of SLR : 19.59590
# SAR of RF : 18.62068
# SAR reduction : 4.9766 %
# iteration = 1920, phi_d = 4.3381547584431246e-05, energy = 0.26652973890304565
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 1950
# SAR of SLR : 19.59590
# SAR of RF : 18.59518
# SAR reduction : 5.1068 %
# iteration = 1950, phi_d = 4.625265137292445e-05, energy = 0.2661646604537964
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 1980
# SAR of SLR : 19.59590
# SAR of RF : 18.56980
# SAR reduction : 5.2363 %
# iteration = 1980, phi_d = 4.940847429679707e-05, energy = 0.2658013701438904
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 2010
# SAR of SLR : 19.59590
# SAR of RF : 18.54455
# SAR reduction : 5.3651 %
# iteration = 2010, phi_d = 5.28309574292507e-05, energy = 0.2654399871826172
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 2040
# SAR of SLR : 19.59590
# SAR of RF : 18.51944
# SAR reduction : 5.4933 %
# iteration = 2040, phi_d = 5.651184619637206e-05, energy = 0.2650805711746216
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 2070
# SAR of SLR : 19.59590
# SAR of RF : 18.49447
# SAR reduction : 5.6207 %
# iteration = 2070, phi_d = 6.0472582845250145e-05, energy = 0.26472318172454834
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 2100
# SAR of SLR : 19.59590
# SAR of RF : 18.46965
# SAR reduction : 5.7473 %
# iteration = 2100, phi_d = 6.471906817751005e-05, energy = 0.2643679678440094
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 2130
# SAR of SLR : 19.59590
# SAR of RF : 18.44499
# SAR reduction : 5.8732 %
# iteration = 2130, phi_d = 6.922941247466952e-05, energy = 0.26401495933532715
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 2160
# SAR of SLR : 19.59590
# SAR of RF : 18.42049
# SAR reduction : 5.9982 %
# iteration = 2160, phi_d = 7.403247582260519e-05, energy = 0.26366427540779114
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 2190
# SAR of SLR : 19.59590
# SAR of RF : 18.39616
# SAR reduction : 6.1224 %
# iteration = 2190, phi_d = 7.912494766060263e-05, energy = 0.26331594586372375
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 2220
# SAR of SLR : 19.59590
# SAR of RF : 18.37200
# SAR reduction : 6.2457 %
# iteration = 2220, phi_d = 8.449825691059232e-05, energy = 0.2629701495170593
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 2250
# SAR of SLR : 19.59590
# SAR of RF : 18.34802
# SAR reduction : 6.3681 %
# iteration = 2250, phi_d = 9.014753595693037e-05, energy = 0.26262688636779785
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 2280
# SAR of SLR : 19.59590
# SAR of RF : 18.32421
# SAR reduction : 6.4895 %
# iteration = 2280, phi_d = 9.610153210815042e-05, energy = 0.2622862160205841
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 2310
# SAR of SLR : 19.59590
# SAR of RF : 18.30061
# SAR reduction : 6.6100 %
# iteration = 2310, phi_d = 0.00010236980597255751, energy = 0.26194828748703003
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 2340
# SAR of SLR : 19.59590
# SAR of RF : 18.27720
# SAR reduction : 6.7295 %
# iteration = 2340, phi_d = 0.00010892513091675937, energy = 0.2616131901741028
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 2370
# SAR of SLR : 19.59590
# SAR of RF : 18.25398
# SAR reduction : 6.8479 %
# iteration = 2370, phi_d = 0.00011574516975088045, energy = 0.26128095388412476
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 2400
# SAR of SLR : 19.59590
# SAR of RF : 18.23098
# SAR reduction : 6.9653 %
# iteration = 2400, phi_d = 0.00012286609853617847, energy = 0.2609516978263855
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 2430
# SAR of SLR : 19.59590
# SAR of RF : 18.20819
# SAR reduction : 7.0816 %
# iteration = 2430, phi_d = 0.00013028096873313189, energy = 0.2606254518032074
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 2460
# SAR of SLR : 19.59590
# SAR of RF : 18.18562
# SAR reduction : 7.1968 %
# iteration = 2460, phi_d = 0.00013799723819829524, energy = 0.2603023648262024
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 2490
# SAR of SLR : 19.59590
# SAR of RF : 18.16327
# SAR reduction : 7.3109 %
# iteration = 2490, phi_d = 0.0001460087369196117, energy = 0.2599824368953705
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 2520
# SAR of SLR : 19.59590
# SAR of RF : 18.14114
# SAR reduction : 7.4238 %
# iteration = 2520, phi_d = 0.0001543182588648051, energy = 0.25966575741767883
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 2550
# SAR of SLR : 19.59590
# SAR of RF : 18.11926
# SAR reduction : 7.5355 %
# iteration = 2550, phi_d = 0.00016288526239804924, energy = 0.2593524754047394
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 2580
# SAR of SLR : 19.59590
# SAR of RF : 18.09761
# SAR reduction : 7.6459 %
# iteration = 2580, phi_d = 0.00017174112144857645, energy = 0.2590425908565521
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 2610
# SAR of SLR : 19.59590
# SAR of RF : 18.07619
# SAR reduction : 7.7552 %
# iteration = 2610, phi_d = 0.00018084874318446964, energy = 0.25873613357543945
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 2640
# SAR of SLR : 19.59590
# SAR of RF : 18.05503
# SAR reduction : 7.8632 %
# iteration = 2640, phi_d = 0.00019028288079425693, energy = 0.2584332227706909
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 2670
# SAR of SLR : 19.59590
# SAR of RF : 18.03412
# SAR reduction : 7.9699 %
# iteration = 2670, phi_d = 0.00019998660718556494, energy = 0.2581339478492737
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 2700
# SAR of SLR : 19.59590
# SAR of RF : 18.01347
# SAR reduction : 8.0753 %
# iteration = 2700, phi_d = 0.00020987521565984935, energy = 0.25783830881118774
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 2730
# SAR of SLR : 19.59590
# SAR of RF : 17.99307
# SAR reduction : 8.1794 %
# iteration = 2730, phi_d = 0.00022013328270986676, energy = 0.2575463652610779
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 2760
# SAR of SLR : 19.59590
# SAR of RF : 17.97294
# SAR reduction : 8.2821 %
# iteration = 2760, phi_d = 0.00023055175552144647, energy = 0.25725823640823364
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 2790
# SAR of SLR : 19.59590
# SAR of RF : 17.95308
# SAR reduction : 8.3835 %
# iteration = 2790, phi_d = 0.0002412690664641559, energy = 0.25697389245033264
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 2820
# SAR of SLR : 19.59590
# SAR of RF : 17.93349
# SAR reduction : 8.4835 %
# iteration = 2820, phi_d = 0.0002522342256270349, energy = 0.25669342279434204
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 2850
# SAR of SLR : 19.59590
# SAR of RF : 17.91417
# SAR reduction : 8.5820 %
# iteration = 2850, phi_d = 0.00026334694121032953, energy = 0.256416916847229
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 2880
# SAR of SLR : 19.59590
# SAR of RF : 17.89512
# SAR reduction : 8.6792 %
# iteration = 2880, phi_d = 0.00027477051480673254, energy = 0.25614434480667114
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 2910
# SAR of SLR : 19.59590
# SAR of RF : 17.87636
# SAR reduction : 8.7750 %
# iteration = 2910, phi_d = 0.00028636574279516935, energy = 0.25587576627731323
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 2940
# SAR of SLR : 19.59590
# SAR of RF : 17.85788
# SAR reduction : 8.8693 %
# iteration = 2940, phi_d = 0.0002981566940434277, energy = 0.25561127066612244
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 2970
# SAR of SLR : 19.59590
# SAR of RF : 17.83969
# SAR reduction : 8.9621 %
# iteration = 2970, phi_d = 0.0003101702022831887, energy = 0.25535082817077637
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 3000
# SAR of SLR : 19.59590
# SAR of RF : 17.82178
# SAR reduction : 9.0535 %
# iteration = 3000, phi_d = 0.00032228176132775843, energy = 0.2550944685935974
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 3030
# SAR of SLR : 19.59590
# SAR of RF : 17.80415
# SAR reduction : 9.1435 %
# iteration = 3030, phi_d = 0.00033458840334787965, energy = 0.25484222173690796
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 3060
# SAR of SLR : 19.59590
# SAR of RF : 17.78682
# SAR reduction : 9.2319 %
# iteration = 3060, phi_d = 0.000347116932971403, energy = 0.2545941472053528
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 3090
# SAR of SLR : 19.59590
# SAR of RF : 17.76978
# SAR reduction : 9.3189 %
# iteration = 3090, phi_d = 0.00035980160464532673, energy = 0.2543502449989319
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 3120
# SAR of SLR : 19.59590
# SAR of RF : 17.75303
# SAR reduction : 9.4043 %
# iteration = 3120, phi_d = 0.00037252166657708585, energy = 0.25411051511764526
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 3150
# SAR of SLR : 19.59590
# SAR of RF : 17.73657
# SAR reduction : 9.4883 %
# iteration = 3150, phi_d = 0.000385408871807158, energy = 0.25387492775917053
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 3180
# SAR of SLR : 19.59590
# SAR of RF : 17.72042
# SAR reduction : 9.5708 %
# iteration = 3180, phi_d = 0.000398439122363925, energy = 0.25364360213279724
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 3210
# SAR of SLR : 19.59590
# SAR of RF : 17.70454
# SAR reduction : 9.6518 %
# iteration = 3210, phi_d = 0.00041154143400490284, energy = 0.2534164488315582
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 3240
# SAR of SLR : 19.59590
# SAR of RF : 17.68897
# SAR reduction : 9.7313 %
# iteration = 3240, phi_d = 0.000424699392169714, energy = 0.2531934976577759
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 3270
# SAR of SLR : 19.59590
# SAR of RF : 17.67369
# SAR reduction : 9.8092 %
# iteration = 3270, phi_d = 0.00043798325350508094, energy = 0.2529747784137726
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 3300
# SAR of SLR : 19.59590
# SAR of RF : 17.65870
# SAR reduction : 9.8857 %
# iteration = 3300, phi_d = 0.0004512912128120661, energy = 0.25276023149490356
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 3330
# SAR of SLR : 19.59590
# SAR of RF : 17.64401
# SAR reduction : 9.9607 %
# iteration = 3330, phi_d = 0.00046465598279610276, energy = 0.2525499165058136
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 3360
# SAR of SLR : 19.59590
# SAR of RF : 17.62960
# SAR reduction : 10.0342 %
# iteration = 3360, phi_d = 0.0004780706367455423, energy = 0.25234371423721313
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 3390
# SAR of SLR : 19.59590
# SAR of RF : 17.61549
# SAR reduction : 10.1062 %
# iteration = 3390, phi_d = 0.0004915375611744821, energy = 0.2521417438983917
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 3420
# SAR of SLR : 19.59590
# SAR of RF : 17.60166
# SAR reduction : 10.1768 %
# iteration = 3420, phi_d = 0.0005049334140494466, energy = 0.2519438564777374
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 3450
# SAR of SLR : 19.59590
# SAR of RF : 17.58813
# SAR reduction : 10.2459 %
# iteration = 3450, phi_d = 0.000518431537784636, energy = 0.251750111579895
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 3480
# SAR of SLR : 19.59590
# SAR of RF : 17.57488
# SAR reduction : 10.3135 %
# iteration = 3480, phi_d = 0.0005318192997947335, energy = 0.2515604496002197
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 3510
# SAR of SLR : 19.59590
# SAR of RF : 17.56191
# SAR reduction : 10.3796 %
# iteration = 3510, phi_d = 0.0005452240002341568, energy = 0.25137487053871155
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 3540
# SAR of SLR : 19.59590
# SAR of RF : 17.54923
# SAR reduction : 10.4444 %
# iteration = 3540, phi_d = 0.0005585970357060432, energy = 0.2511933147907257
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 3570
# SAR of SLR : 19.59590
# SAR of RF : 17.53683
# SAR reduction : 10.5077 %
# iteration = 3570, phi_d = 0.0005719683831557631, energy = 0.2510158121585846
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 3600
# SAR of SLR : 19.59590
# SAR of RF : 17.52470
# SAR reduction : 10.5695 %
# iteration = 3600, phi_d = 0.000585216679610312, energy = 0.25084224343299866
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 3630
# SAR of SLR : 19.59590
# SAR of RF : 17.51285
# SAR reduction : 10.6300 %
# iteration = 3630, phi_d = 0.0005984088638797402, energy = 0.2506726086139679
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 3660
# SAR of SLR : 19.59590
# SAR of RF : 17.50127
# SAR reduction : 10.6891 %
# iteration = 3660, phi_d = 0.000611479626968503, energy = 0.2505068778991699
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 3690
# SAR of SLR : 19.59590
# SAR of RF : 17.48996
# SAR reduction : 10.7468 %
# iteration = 3690, phi_d = 0.000624601321760565, energy = 0.25034499168395996
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 3720
# SAR of SLR : 19.59590
# SAR of RF : 17.47892
# SAR reduction : 10.8032 %
# iteration = 3720, phi_d = 0.0006375451339408755, energy = 0.2501869201660156
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 3750
# SAR of SLR : 19.59590
# SAR of RF : 17.46814
# SAR reduction : 10.8582 %
# iteration = 3750, phi_d = 0.000650368514470756, energy = 0.2500326335430145
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 3780
# SAR of SLR : 19.59590
# SAR of RF : 17.45762
# SAR reduction : 10.9119 %
# iteration = 3780, phi_d = 0.0006631053984165192, energy = 0.2498820424079895
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 3810
# SAR of SLR : 19.59590
# SAR of RF : 17.44736
# SAR reduction : 10.9642 %
# iteration = 3810, phi_d = 0.0006757376249879599, energy = 0.24973514676094055
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 3840
# SAR of SLR : 19.59590
# SAR of RF : 17.43735
# SAR reduction : 11.0153 %
# iteration = 3840, phi_d = 0.0006881803274154663, energy = 0.2495918571949005
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 3870
# SAR of SLR : 19.59590
# SAR of RF : 17.42758
# SAR reduction : 11.0651 %
# iteration = 3870, phi_d = 0.0007004847284406424, energy = 0.2494521141052246
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 3900
# SAR of SLR : 19.59590
# SAR of RF : 17.41807
# SAR reduction : 11.1137 %
# iteration = 3900, phi_d = 0.0007126834825612605, energy = 0.24931590259075165
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 3930
# SAR of SLR : 19.59590
# SAR of RF : 17.40879
# SAR reduction : 11.1610 %
# iteration = 3930, phi_d = 0.0007247267058119178, energy = 0.24918311834335327
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 3960
# SAR of SLR : 19.59590
# SAR of RF : 17.39976
# SAR reduction : 11.2071 %
# iteration = 3960, phi_d = 0.0007366750505752861, energy = 0.24905382096767426
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 3990
# SAR of SLR : 19.59590
# SAR of RF : 17.39095
# SAR reduction : 11.2521 %
# iteration = 3990, phi_d = 0.000748409132938832, energy = 0.2489277869462967
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 4020
# SAR of SLR : 19.59590
# SAR of RF : 17.38238
# SAR reduction : 11.2958 %
# iteration = 4020, phi_d = 0.0007600149838253856, energy = 0.24880507588386536
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 4050
# SAR of SLR : 19.59590
# SAR of RF : 17.37403
# SAR reduction : 11.3384 %
# iteration = 4050, phi_d = 0.0007713740924373269, energy = 0.2486855685710907
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 4080
# SAR of SLR : 19.59590
# SAR of RF : 17.36590
# SAR reduction : 11.3799 %
# iteration = 4080, phi_d = 0.0007826076471246779, energy = 0.24856925010681152
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 4110
# SAR of SLR : 19.59590
# SAR of RF : 17.35800
# SAR reduction : 11.4202 %
# iteration = 4110, phi_d = 0.0007935884641483426, energy = 0.24845609068870544
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 4140
# SAR of SLR : 19.59590
# SAR of RF : 17.35030
# SAR reduction : 11.4595 %
# iteration = 4140, phi_d = 0.0008044871501624584, energy = 0.24834591150283813
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 4170
# SAR of SLR : 19.59590
# SAR of RF : 17.34281
# SAR reduction : 11.4977 %
# iteration = 4170, phi_d = 0.0008152156369760633, energy = 0.24823878705501556
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 4200
# SAR of SLR : 19.59590
# SAR of RF : 17.33553
# SAR reduction : 11.5349 %
# iteration = 4200, phi_d = 0.0008256941218860447, energy = 0.2481345534324646
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 4230
# SAR of SLR : 19.59590
# SAR of RF : 17.32845
# SAR reduction : 11.5710 %
# iteration = 4230, phi_d = 0.0008359904168173671, energy = 0.24803324043750763
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 4260
# SAR of SLR : 19.59590
# SAR of RF : 17.32157
# SAR reduction : 11.6061 %
# iteration = 4260, phi_d = 0.0008461294928565621, energy = 0.2479347139596939
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 4290
# SAR of SLR : 19.59590
# SAR of RF : 17.31488
# SAR reduction : 11.6403 %
# iteration = 4290, phi_d = 0.0008560686255805194, energy = 0.24783894419670105
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 4320
# SAR of SLR : 19.59590
# SAR of RF : 17.30838
# SAR reduction : 11.6735 %
# iteration = 4320, phi_d = 0.0008658478036522865, energy = 0.24774587154388428
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 4350
# SAR of SLR : 19.59590
# SAR of RF : 17.30206
# SAR reduction : 11.7057 %
# iteration = 4350, phi_d = 0.0008753964793868363, energy = 0.24765545129776
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 4380
# SAR of SLR : 19.59590
# SAR of RF : 17.29592
# SAR reduction : 11.7370 %
# iteration = 4380, phi_d = 0.000884733279235661, energy = 0.24756759405136108
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 4410
# SAR of SLR : 19.59590
# SAR of RF : 17.28996
# SAR reduction : 11.7674 %
# iteration = 4410, phi_d = 0.000893858727067709, energy = 0.2474822998046875
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 4440
# SAR of SLR : 19.59590
# SAR of RF : 17.28417
# SAR reduction : 11.7970 %
# iteration = 4440, phi_d = 0.0009029128705151379, energy = 0.24739941954612732
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 4470
# SAR of SLR : 19.59590
# SAR of RF : 17.27855
# SAR reduction : 11.8257 %
# iteration = 4470, phi_d = 0.0009115824941545725, energy = 0.24731895327568054
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 4500
# SAR of SLR : 19.59590
# SAR of RF : 17.27310
# SAR reduction : 11.8535 %
# iteration = 4500, phi_d = 0.0009202000219374895, energy = 0.2472408413887024
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 4530
# SAR of SLR : 19.59590
# SAR of RF : 17.26780
# SAR reduction : 11.8805 %
# iteration = 4530, phi_d = 0.0009285706328228116, energy = 0.2471650242805481
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 4560
# SAR of SLR : 19.59590
# SAR of RF : 17.26266
# SAR reduction : 11.9068 %
# iteration = 4560, phi_d = 0.0009368096943944693, energy = 0.24709142744541168
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 4590
# SAR of SLR : 19.59590
# SAR of RF : 17.25767
# SAR reduction : 11.9322 %
# iteration = 4590, phi_d = 0.0009448669152334332, energy = 0.24702003598213196
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 4620
# SAR of SLR : 19.59590
# SAR of RF : 17.25283
# SAR reduction : 11.9569 %
# iteration = 4620, phi_d = 0.0009526501526124775, energy = 0.24695074558258057
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 4650
# SAR of SLR : 19.59590
# SAR of RF : 17.24813
# SAR reduction : 11.9809 %
# iteration = 4650, phi_d = 0.0009603298967704177, energy = 0.2468835562467575
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 4680
# SAR of SLR : 19.59590
# SAR of RF : 17.24358
# SAR reduction : 12.0041 %
# iteration = 4680, phi_d = 0.0009677329799160361, energy = 0.24681836366653442
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 4710
# SAR of SLR : 19.59590
# SAR of RF : 17.23916
# SAR reduction : 12.0267 %
# iteration = 4710, phi_d = 0.000975028844550252, energy = 0.24675513803958893
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 4740
# SAR of SLR : 19.59590
# SAR of RF : 17.23488
# SAR reduction : 12.0485 %
# iteration = 4740, phi_d = 0.000982183963060379, energy = 0.24669381976127625
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 4770
# SAR of SLR : 19.59590
# SAR of RF : 17.23072
# SAR reduction : 12.0697 %
# iteration = 4770, phi_d = 0.0009890776127576828, energy = 0.2466343343257904
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 4800
# SAR of SLR : 19.59590
# SAR of RF : 17.22670
# SAR reduction : 12.0903 %
# iteration = 4800, phi_d = 0.0009958415757864714, energy = 0.246576726436615
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 4830
# SAR of SLR : 19.59590
# SAR of RF : 17.22279
# SAR reduction : 12.1102 %
# iteration = 4830, phi_d = 0.001002444070763886, energy = 0.24652084708213806
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 4860
# SAR of SLR : 19.59590
# SAR of RF : 17.21901
# SAR reduction : 12.1295 %
# iteration = 4860, phi_d = 0.0010088065173476934, energy = 0.246466726064682
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 4890
# SAR of SLR : 19.59590
# SAR of RF : 17.21535
# SAR reduction : 12.1482 %
# iteration = 4890, phi_d = 0.0010150568559765816, energy = 0.24641422927379608
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 4920
# SAR of SLR : 19.59590
# SAR of RF : 17.21179
# SAR reduction : 12.1663 %
# iteration = 4920, phi_d = 0.0010211952030658722, energy = 0.24636337161064148
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 4950
# SAR of SLR : 19.59590
# SAR of RF : 17.20835
# SAR reduction : 12.1839 %
# iteration = 4950, phi_d = 0.0010270432103425264, energy = 0.24631407856941223
# ★★★★★★★★★★★★★★★★★★★★★★★★
# Iteration : 4980
# SAR of SLR : 19.59590
# SAR of RF : 17.20501
# SAR reduction : 12.2009 %
# iteration = 4980, phi_d = 0.0010328253265470266, energy = 0.24626633524894714
# Total time: 1709.0

# %%
savemat("OC_result_inv8_best_mu00002_STA.mat", {"L2loss": L2_loss, "sar_loss" : sar_loss, "w1" : w1, "w2" : w2, "total loss" : total_loss, "iteration" : e})
